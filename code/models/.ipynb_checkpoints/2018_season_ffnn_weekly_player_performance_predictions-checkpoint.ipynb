# %%
# DataFrame manipulation libraries:
import pandas as pd
import numpy as np

# Visualization libraries:
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Evaluation and processing libraries:
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Keras libraries:
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, Dropout, GRU
from keras.optimizers import Adam
from keras.preprocessing.sequence import TimeseriesGenerator
# Out:
# Using TensorFlow backend.

# %%
# Load in CSV data of top player performance per week in the 2015, 2016, 2017, and 2018 NFL seasons:
df = pd.read_csv('../../clean_data/player_weekly_performance_2018.csv')
df.head()  # preview first 5 rows of dataframe
# Out:
#    Rank  PlayerID              Name Team Position  Week Opponent  \
# 0     1      8283  Ryan Fitzpatrick   TB       QB     1       NO
# 1     2     18878      Alvin Kamara   NO       RB     1       TB
# 2     3      7242        Drew Brees   NO       QB     1       TB
# 3     4     18082       Tyreek Hill   KC       WR     1      LAC
# 4     5     18983      James Conner  PIT       RB     1      CLE
#
#    PassingYards  PassingTouchdowns  PassingInterceptions  RushingYards  \
# 0           417                  4                     0            36
# 1             0                  0                     0            29
# 2           439                  3                     0             0
# 3             0                  0                     0             4
# 4             0                  0                     0           135
#
#    RushingTouchdowns  Receptions  ReceivingYards  ReceivingTouchdowns  \
# 0                  1           0               0                    0
# 1                  2           9             112                    1
# 2                  0           0               0                    0
# 3                  0           7             169                    2
# 4                  2           5              57                    0
#
#    FumblesLost  FantasyPoints        Date  Year
# 0            0          42.28  2018-09-09  2018
# 1            0          34.10  2018-09-09  2018
# 2            0          31.56  2018-09-09  2018
# 3            0          29.30  2018-09-09  2018
# 4            1          29.20  2018-09-09  2018

# %%
df['Date'] = pd.to_datetime(df['Date'], format = '%Y-%m-%d') # Convert 'Date' feature into a Pandas datetime object
df.dtypes  # examine data types of features
# Out:
# Rank                             int64
# PlayerID                         int64
# Name                            object
# Team                            object
# Position                        object
# Week                             int64
# Opponent                        object
# PassingYards                     int64
# PassingTouchdowns                int64
# PassingInterceptions             int64
# RushingYards                     int64
# RushingTouchdowns                int64
# Receptions                       int64
# ReceivingYards                   int64
# ReceivingTouchdowns              int64
# FumblesLost                      int64
# FantasyPoints                  float64
# Date                    datetime64[ns]
# Year                             int64
# dtype: object

# %%
df.set_index('Date', inplace=True)  # set Date as the index
df.sort_index(inplace=True)         # sort the dataframe by the Date index
df.head()                           # examine first 5 rows to verify changes
# Out:
#             Rank  PlayerID              Name Team Position  Week Opponent  \
# Date
# 2018-09-09     1      8283  Ryan Fitzpatrick   TB       QB     1       NO
# 2018-09-09     2     18878      Alvin Kamara   NO       RB     1       TB
# 2018-09-09     3      7242        Drew Brees   NO       QB     1       TB
# 2018-09-09     4     18082       Tyreek Hill   KC       WR     1      LAC
# 2018-09-09     5     18983      James Conner  PIT       RB     1      CLE
#
#             PassingYards  PassingTouchdowns  PassingInterceptions  \
# Date
# 2018-09-09           417                  4                     0
# 2018-09-09             0                  0                     0
# 2018-09-09           439                  3                     0
# 2018-09-09             0                  0                     0
# 2018-09-09             0                  0                     0
#
#             RushingYards  RushingTouchdowns  Receptions  ReceivingYards  \
# Date
# 2018-09-09            36                  1           0               0
# 2018-09-09            29                  2           9             112
# 2018-09-09             0                  0           0               0
# 2018-09-09             4                  0           7             169
# 2018-09-09           135                  2           5              57
#
#             ReceivingTouchdowns  FumblesLost  FantasyPoints  Year
# Date
# 2018-09-09                    0            0          42.28  2018
# 2018-09-09                    1            0          34.10  2018
# 2018-09-09                    0            0          31.56  2018
# 2018-09-09                    2            0          29.30  2018
# 2018-09-09                    0            1          29.20  2018

# %%
df.shape  # preview dataframe dimensions; 20,400 rows and 17 columns as features
# Out:
# (5100, 18)

# %%
# Convert player's team, opponent, and position into one-hot encoded variables to use for FFNN:
df_with_dummies = pd.get_dummies(df, columns=['Team', 'Opponent'], drop_first=False)

# Select feature variables to convert into floats; prevents errors when scaling data with StandardScaler:
features = [col for col in df_with_dummies.columns if col not in ['Name', 'Position', 'Week', 'Year', 'PlayerID']]
df_with_dummies[features] = df_with_dummies[features].astype(float)

# Assign X as features to be used for predicting weekly fantasy points per player:
X = df_with_dummies[[col for col in df_with_dummies.columns if col not in ['FantasyPoints', 'PlayerID']]]
# Assign target vector y as weekly fantasy points per player:
y = df_with_dummies['FantasyPoints']

# %%
X.dtypes  # verify that data types have been properly cast
# Out:
# Rank                    float64
# Name                     object
# Position                 object
# Week                      int64
# PassingYards            float64
# PassingTouchdowns       float64
# PassingInterceptions    float64
# RushingYards            float64
# RushingTouchdowns       float64
# Receptions              float64
# ReceivingYards          float64
# ReceivingTouchdowns     float64
# FumblesLost             float64
# Year                      int64
# Team_ARI                float64
# Team_ATL                float64
# Team_BAL                float64
# Team_BUF                float64
# Team_CAR                float64
# Team_CHI                float64
# Team_CIN                float64
# Team_CLE                float64
# Team_DAL                float64
# Team_DEN                float64
# Team_DET                float64
# Team_GB                 float64
# Team_HOU                float64
# Team_IND                float64
# Team_JAX                float64
# Team_KC                 float64
#                          ...
# Opponent_BAL            float64
# Opponent_BUF            float64
# Opponent_CAR            float64
# Opponent_CHI            float64
# Opponent_CIN            float64
# Opponent_CLE            float64
# Opponent_DAL            float64
# Opponent_DEN            float64
# Opponent_DET            float64
# Opponent_GB             float64
# Opponent_HOU            float64
# Opponent_IND            float64
# Opponent_JAX            float64
# Opponent_KC             float64
# Opponent_LAC            float64
# Opponent_LAR            float64
# Opponent_MIA            float64
# Opponent_MIN            float64
# Opponent_NE             float64
# Opponent_NO             float64
# Opponent_NYG            float64
# Opponent_NYJ            float64
# Opponent_OAK            float64
# Opponent_PHI            float64
# Opponent_PIT            float64
# Opponent_SEA            float64
# Opponent_SF             float64
# Opponent_TB             float64
# Opponent_TEN            float64
# Opponent_WAS            float64
# Length: 78, dtype: object

# %%
# Split X and y data into a training set and validation set:
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Scale all columns to use as predictive features using StandardScaler:
ss = StandardScaler()
X_train_sc = ss.fit_transform(X_train.drop(columns = ['Name', 'Position', 'Week', 'Year']))
X_test_sc = ss.transform(X_test.drop(columns = ['Name', 'Position', 'Week', 'Year']))

# %%
X_test_sc[0:5]  # preview first 5 scaled X values in the validation data
# Out:
# array([[-0.07630398, -0.31715918, -0.26621033, -0.20776738, -0.45487011,
#         -0.26056741,  1.15984546,  0.66307007, -0.39695878, -0.19570613,
#         -0.17684817, -0.18074121, -0.19346525, -0.19053746, -0.17367869,
#         -0.17447582, -0.16718097, -0.18151105, -0.18380366, -0.18227804,
#         -0.18831599, -0.17996851, -0.17684817, -0.18151105,  5.89471488,
#         -0.18074121, -0.17684817, -0.16215612, -0.17996851, -0.17841432,
#         -0.19273688, -0.18304223, -0.17684817, -0.17606051, -0.19200614,
#         -0.18151105, -0.17841432, -0.17919289, -0.17447582, -0.17606051,
#         -0.18074121, -0.17367869, -0.18074121, -0.19273688, -0.17367869,
#         -0.17919289, -0.17841432, -0.18456235, -0.18304223, -0.17447582,
#         -0.17763276, -0.17606051, -0.18227804, -0.17919289, -0.19200614,
#         -0.17526974, -0.17526974, -0.18831599, -0.17606051, -0.17126767,
#         -0.17996851, -0.17207467, -0.18074121, -0.16964349, -0.18682237,
#         -0.18380366, -0.18531834, -0.17287832, -0.17996851, -0.17526974,
#         -0.17919289, -0.17526974,  5.3526781 , -0.17684817],
#        [ 0.81502704, -0.31715918, -0.26621033, -0.20776738, -0.37688714,
#         -0.26056741, -0.5215678 , -0.30377122, -0.39695878, -0.19570613,
#         -0.17684817, -0.18074121, -0.19346525, -0.19053746, -0.17367869,
#         -0.17447582, -0.16718097, -0.18151105, -0.18380366, -0.18227804,
#         -0.18831599, -0.17996851, -0.17684817,  5.50930658, -0.16964349,
#         -0.18074121, -0.17684817, -0.16215612, -0.17996851, -0.17841432,
#         -0.19273688, -0.18304223, -0.17684817, -0.17606051, -0.19200614,
#         -0.18151105, -0.17841432, -0.17919289, -0.17447582, -0.17606051,
#         -0.18074121, -0.17367869, -0.18074121, -0.19273688, -0.17367869,
#         -0.17919289, -0.17841432, -0.18456235, -0.18304223, -0.17447582,
#         -0.17763276, -0.17606051, -0.18227804, -0.17919289, -0.19200614,
#         -0.17526974,  5.70549135, -0.18831599, -0.17606051, -0.17126767,
#         -0.17996851, -0.17207467, -0.18074121, -0.16964349, -0.18682237,
#         -0.18380366, -0.18531834, -0.17287832, -0.17996851, -0.17526974,
#         -0.17919289, -0.17526974, -0.18682237, -0.17684817],
#        [ 1.18842246, -0.31715918, -0.26621033, -0.20776738, -0.33789565,
#         -0.26056741, -0.10121448, -0.58446707, -0.39695878, -0.19570613,
#         -0.17684817, -0.18074121, -0.19346525, -0.19053746, -0.17367869,
#         -0.17447582, -0.16718097, -0.18151105, -0.18380366, -0.18227804,
#         -0.18831599, -0.17996851, -0.17684817, -0.18151105, -0.16964349,
#         -0.18074121, -0.17684817, -0.16215612,  5.55652769, -0.17841432,
#         -0.19273688, -0.18304223, -0.17684817, -0.17606051, -0.19200614,
#         -0.18151105, -0.17841432, -0.17919289, -0.17447582, -0.17606051,
#         -0.18074121, -0.17367869, -0.18074121, -0.19273688, -0.17367869,
#         -0.17919289, -0.17841432, -0.18456235, -0.18304223, -0.17447582,
#         -0.17763276, -0.17606051, -0.18227804, -0.17919289, -0.19200614,
#         -0.17526974, -0.17526974, -0.18831599, -0.17606051, -0.17126767,
#         -0.17996851, -0.17207467, -0.18074121, -0.16964349, -0.18682237,
#         -0.18380366,  5.39611992, -0.17287832, -0.17996851, -0.17526974,
#         -0.17919289, -0.17526974, -0.18682237, -0.17684817],
#        [-0.99172503, -0.31715918, -0.26621033, -0.20776738,  0.90983197,
#          2.69691134, -0.10121448, -0.36614807, -0.39695878, -0.19570613,
#         -0.17684817, -0.18074121, -0.19346525, -0.19053746, -0.17367869,
#         -0.17447582, -0.16718097, -0.18151105,  5.4405882 , -0.18227804,
#         -0.18831599, -0.17996851, -0.17684817, -0.18151105, -0.16964349,
#         -0.18074121, -0.17684817, -0.16215612, -0.17996851, -0.17841432,
#         -0.19273688, -0.18304223, -0.17684817, -0.17606051, -0.19200614,
#         -0.18151105, -0.17841432, -0.17919289, -0.17447582, -0.17606051,
#         -0.18074121, -0.17367869, -0.18074121, -0.19273688, -0.17367869,
#         -0.17919289, -0.17841432, -0.18456235, -0.18304223, -0.17447582,
#         -0.17763276, -0.17606051, -0.18227804, -0.17919289, -0.19200614,
#         -0.17526974, -0.17526974, -0.18831599, -0.17606051, -0.17126767,
#         -0.17996851, -0.17207467, -0.18074121, -0.16964349,  5.3526781 ,
#         -0.18380366, -0.18531834, -0.17287832, -0.17996851, -0.17526974,
#         -0.17919289, -0.17526974, -0.18682237, -0.17684817],
#        [-0.79900481, -0.31715918, -0.26621033, -0.20776738, -0.45487011,
#         -0.26056741,  1.58019878,  2.37843364, -0.39695878, -0.19570613,
#         -0.17684817, -0.18074121, -0.19346525, -0.19053746, -0.17367869,
#         -0.17447582, -0.16718097, -0.18151105, -0.18380366, -0.18227804,
#         -0.18831599, -0.17996851, -0.17684817, -0.18151105, -0.16964349,
#         -0.18074121, -0.17684817, -0.16215612, -0.17996851,  5.60493124,
#         -0.19273688, -0.18304223, -0.17684817, -0.17606051, -0.19200614,
#         -0.18151105, -0.17841432, -0.17919289, -0.17447582, -0.17606051,
#         -0.18074121, -0.17367869, -0.18074121, -0.19273688, -0.17367869,
#         -0.17919289, -0.17841432, -0.18456235, -0.18304223, -0.17447582,
#         -0.17763276, -0.17606051, -0.18227804, -0.17919289, -0.19200614,
#         -0.17526974, -0.17526974, -0.18831599, -0.17606051, -0.17126767,
#         -0.17996851, -0.17207467, -0.18074121, -0.16964349, -0.18682237,
#         -0.18380366, -0.18531834, -0.17287832, -0.17996851, -0.17526974,
#          5.58057857, -0.17526974, -0.18682237, -0.17684817]])

# %%
X_test_sc.shape  # check shape of scaled X validation data
# Out:
# (1275, 74)

# %%
# Instantiate and build feed-forward neural network to predict player performance per week:
model = Sequential()                                        # instantiate model
model.add(Dense(74, activation='relu', input_shape=(74,)))  # input layer with 74 neurons
model.add(Dense(74, activation='relu'))                     # first hidden layer with 74 neurons
model.add(Dense(37, activation='relu'))                     # second hidden layer with 37 neurons
model.add(Dense(1))                                         # output layer with 1 neuron; represents predicted points
# Out:
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=15, verbose=1, mode='auto')

# %%
# Compile the FFNN model:
model.compile(loss='mse', optimizer='adam', metrics=['mae'])
# loss function = mean squared error
# optimization function = adam
# evaluation metric = mean absolute error

# %%
# Train the FFNN model using training, error is measured using validation data:
history = model.fit(X_train_sc, y_train, validation_data=(X_test_sc, y_test), epochs=120, 
                    batch_size=256) #, callbacks = [early_stop])
# Out:
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 3825 samples, validate on 1275 samples
# Epoch 1/120
# 3825/3825 [==============================] - 0s 90us/step - loss: 77.5751 - mean_absolute_error: 5.7690 - val_loss: 49.9705 - val_mean_absolute_error: 4.7658
# Epoch 2/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 43.7467 - mean_absolute_error: 4.9744 - val_loss: 33.0271 - val_mean_absolute_error: 4.8484
# Epoch 3/120
# 3825/3825 [==============================] - 0s 16us/step - loss: 28.4832 - mean_absolute_error: 4.4564 - val_loss: 20.2206 - val_mean_absolute_error: 3.7266
# Epoch 4/120
# 3825/3825 [==============================] - 0s 17us/step - loss: 15.8858 - mean_absolute_error: 3.2345 - val_loss: 10.8200 - val_mean_absolute_error: 2.6993
# Epoch 5/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 7.4911 - mean_absolute_error: 2.1938 - val_loss: 4.6433 - val_mean_absolute_error: 1.6850
# Epoch 6/120
# 3825/3825 [==============================] - 0s 17us/step - loss: 3.0361 - mean_absolute_error: 1.3102 - val_loss: 2.0601 - val_mean_absolute_error: 1.0758
# Epoch 7/120
# 3825/3825 [==============================] - 0s 17us/step - loss: 1.5215 - mean_absolute_error: 0.9170 - val_loss: 1.3319 - val_mean_absolute_error: 0.8616
# Epoch 8/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 1.0789 - mean_absolute_error: 0.7815 - val_loss: 1.0633 - val_mean_absolute_error: 0.7843
# Epoch 9/120
# 3825/3825 [==============================] - 0s 19us/step - loss: 0.8608 - mean_absolute_error: 0.7071 - val_loss: 0.9060 - val_mean_absolute_error: 0.7265
# Epoch 10/120
# 3825/3825 [==============================] - 0s 19us/step - loss: 0.7247 - mean_absolute_error: 0.6475 - val_loss: 0.7942 - val_mean_absolute_error: 0.6790
# Epoch 11/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.6192 - mean_absolute_error: 0.5982 - val_loss: 0.7023 - val_mean_absolute_error: 0.6370
# Epoch 12/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.5395 - mean_absolute_error: 0.5568 - val_loss: 0.6275 - val_mean_absolute_error: 0.6012
# Epoch 13/120
# 3825/3825 [==============================] - 0s 16us/step - loss: 0.4729 - mean_absolute_error: 0.5186 - val_loss: 0.5749 - val_mean_absolute_error: 0.5721
# Epoch 14/120
# 3825/3825 [==============================] - 0s 17us/step - loss: 0.4184 - mean_absolute_error: 0.4866 - val_loss: 0.5224 - val_mean_absolute_error: 0.5459
# Epoch 15/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.3779 - mean_absolute_error: 0.4619 - val_loss: 0.4829 - val_mean_absolute_error: 0.5219
# Epoch 16/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.3400 - mean_absolute_error: 0.4375 - val_loss: 0.4591 - val_mean_absolute_error: 0.5029
# Epoch 17/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.3140 - mean_absolute_error: 0.4182 - val_loss: 0.4291 - val_mean_absolute_error: 0.4849
# Epoch 18/120
# 3825/3825 [==============================] - 0s 16us/step - loss: 0.2881 - mean_absolute_error: 0.4006 - val_loss: 0.4006 - val_mean_absolute_error: 0.4686
# Epoch 19/120
# 3825/3825 [==============================] - 0s 16us/step - loss: 0.2643 - mean_absolute_error: 0.3839 - val_loss: 0.3799 - val_mean_absolute_error: 0.4589
# Epoch 20/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.2461 - mean_absolute_error: 0.3690 - val_loss: 0.3619 - val_mean_absolute_error: 0.4439
# Epoch 21/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.2295 - mean_absolute_error: 0.3555 - val_loss: 0.3462 - val_mean_absolute_error: 0.4330
# Epoch 22/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.2149 - mean_absolute_error: 0.3426 - val_loss: 0.3317 - val_mean_absolute_error: 0.4232
# Epoch 23/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.2017 - mean_absolute_error: 0.3321 - val_loss: 0.3217 - val_mean_absolute_error: 0.4122
# Epoch 24/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.1923 - mean_absolute_error: 0.3232 - val_loss: 0.3145 - val_mean_absolute_error: 0.4048
# Epoch 25/120
# 3825/3825 [==============================] - 0s 16us/step - loss: 0.1838 - mean_absolute_error: 0.3146 - val_loss: 0.3035 - val_mean_absolute_error: 0.3979
# Epoch 26/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.1707 - mean_absolute_error: 0.3029 - val_loss: 0.2875 - val_mean_absolute_error: 0.3888
# Epoch 27/120
# 3825/3825 [==============================] - 0s 16us/step - loss: 0.1619 - mean_absolute_error: 0.2948 - val_loss: 0.2846 - val_mean_absolute_error: 0.3847
# Epoch 28/120
# 3825/3825 [==============================] - 0s 16us/step - loss: 0.1544 - mean_absolute_error: 0.2870 - val_loss: 0.2762 - val_mean_absolute_error: 0.3788
# Epoch 29/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.1473 - mean_absolute_error: 0.2809 - val_loss: 0.2699 - val_mean_absolute_error: 0.3717
# Epoch 30/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.1404 - mean_absolute_error: 0.2731 - val_loss: 0.2650 - val_mean_absolute_error: 0.3696
# Epoch 31/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.1357 - mean_absolute_error: 0.2686 - val_loss: 0.2593 - val_mean_absolute_error: 0.3620
# Epoch 32/120
# 3825/3825 [==============================] - 0s 16us/step - loss: 0.1306 - mean_absolute_error: 0.2628 - val_loss: 0.2570 - val_mean_absolute_error: 0.3596
# Epoch 33/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.1257 - mean_absolute_error: 0.2573 - val_loss: 0.2505 - val_mean_absolute_error: 0.3576
# Epoch 34/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.1215 - mean_absolute_error: 0.2525 - val_loss: 0.2481 - val_mean_absolute_error: 0.3510
# Epoch 35/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.1170 - mean_absolute_error: 0.2481 - val_loss: 0.2419 - val_mean_absolute_error: 0.3472
# Epoch 36/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.1131 - mean_absolute_error: 0.2431 - val_loss: 0.2411 - val_mean_absolute_error: 0.3501
# Epoch 37/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.1085 - mean_absolute_error: 0.2383 - val_loss: 0.2375 - val_mean_absolute_error: 0.3453
# Epoch 38/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.1055 - mean_absolute_error: 0.2334 - val_loss: 0.2319 - val_mean_absolute_error: 0.3388
# Epoch 39/120
# 3825/3825 [==============================] - 0s 16us/step - loss: 0.1014 - mean_absolute_error: 0.2305 - val_loss: 0.2312 - val_mean_absolute_error: 0.3366
# Epoch 40/120
# 3825/3825 [==============================] - 0s 16us/step - loss: 0.0993 - mean_absolute_error: 0.2266 - val_loss: 0.2283 - val_mean_absolute_error: 0.3343
# Epoch 41/120
# 3825/3825 [==============================] - 0s 16us/step - loss: 0.0957 - mean_absolute_error: 0.2235 - val_loss: 0.2272 - val_mean_absolute_error: 0.3323
# Epoch 42/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0929 - mean_absolute_error: 0.2200 - val_loss: 0.2217 - val_mean_absolute_error: 0.3279
# Epoch 43/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0903 - mean_absolute_error: 0.2162 - val_loss: 0.2240 - val_mean_absolute_error: 0.3310
# Epoch 44/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.0886 - mean_absolute_error: 0.2147 - val_loss: 0.2182 - val_mean_absolute_error: 0.3263
# Epoch 45/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.0870 - mean_absolute_error: 0.2116 - val_loss: 0.2238 - val_mean_absolute_error: 0.3295
# Epoch 46/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.0845 - mean_absolute_error: 0.2085 - val_loss: 0.2160 - val_mean_absolute_error: 0.3213
# Epoch 47/120
# 3825/3825 [==============================] - 0s 20us/step - loss: 0.0821 - mean_absolute_error: 0.2060 - val_loss: 0.2127 - val_mean_absolute_error: 0.3194
# Epoch 48/120
# 3825/3825 [==============================] - 0s 21us/step - loss: 0.0796 - mean_absolute_error: 0.2019 - val_loss: 0.2137 - val_mean_absolute_error: 0.3203
# Epoch 49/120
# 3825/3825 [==============================] - 0s 16us/step - loss: 0.0771 - mean_absolute_error: 0.1989 - val_loss: 0.2129 - val_mean_absolute_error: 0.3181
# Epoch 50/120
# 3825/3825 [==============================] - 0s 21us/step - loss: 0.0752 - mean_absolute_error: 0.1962 - val_loss: 0.2102 - val_mean_absolute_error: 0.3153
# Epoch 51/120
# 3825/3825 [==============================] - 0s 19us/step - loss: 0.0735 - mean_absolute_error: 0.1936 - val_loss: 0.2100 - val_mean_absolute_error: 0.3141
# Epoch 52/120
# 3825/3825 [==============================] - 0s 16us/step - loss: 0.0715 - mean_absolute_error: 0.1917 - val_loss: 0.2113 - val_mean_absolute_error: 0.3134
# Epoch 53/120
# 3825/3825 [==============================] - 0s 16us/step - loss: 0.0705 - mean_absolute_error: 0.1890 - val_loss: 0.2055 - val_mean_absolute_error: 0.3112
# Epoch 54/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0679 - mean_absolute_error: 0.1857 - val_loss: 0.2065 - val_mean_absolute_error: 0.3108
# Epoch 55/120
# 3825/3825 [==============================] - 0s 22us/step - loss: 0.0670 - mean_absolute_error: 0.1843 - val_loss: 0.2049 - val_mean_absolute_error: 0.3097
# Epoch 56/120
# 3825/3825 [==============================] - 0s 23us/step - loss: 0.0648 - mean_absolute_error: 0.1811 - val_loss: 0.2055 - val_mean_absolute_error: 0.3101
# Epoch 57/120
# 3825/3825 [==============================] - 0s 21us/step - loss: 0.0645 - mean_absolute_error: 0.1805 - val_loss: 0.2049 - val_mean_absolute_error: 0.3096
# Epoch 58/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0633 - mean_absolute_error: 0.1782 - val_loss: 0.2022 - val_mean_absolute_error: 0.3053
# Epoch 59/120
# 3825/3825 [==============================] - 0s 10us/step - loss: 0.0616 - mean_absolute_error: 0.1755 - val_loss: 0.2045 - val_mean_absolute_error: 0.3076
# Epoch 60/120
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0603 - mean_absolute_error: 0.1739 - val_loss: 0.2010 - val_mean_absolute_error: 0.3036
# Epoch 61/120
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0597 - mean_absolute_error: 0.1728 - val_loss: 0.2011 - val_mean_absolute_error: 0.3050
# Epoch 62/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0580 - mean_absolute_error: 0.1707 - val_loss: 0.2019 - val_mean_absolute_error: 0.3038
# Epoch 63/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0571 - mean_absolute_error: 0.1683 - val_loss: 0.1988 - val_mean_absolute_error: 0.3025
# Epoch 64/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0554 - mean_absolute_error: 0.1669 - val_loss: 0.1994 - val_mean_absolute_error: 0.3009
# Epoch 65/120
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0545 - mean_absolute_error: 0.1649 - val_loss: 0.2012 - val_mean_absolute_error: 0.3014
# Epoch 66/120
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0544 - mean_absolute_error: 0.1644 - val_loss: 0.1980 - val_mean_absolute_error: 0.2999
# Epoch 67/120
# 3825/3825 [==============================] - 0s 10us/step - loss: 0.0530 - mean_absolute_error: 0.1621 - val_loss: 0.1997 - val_mean_absolute_error: 0.3001
# Epoch 68/120
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0522 - mean_absolute_error: 0.1603 - val_loss: 0.1959 - val_mean_absolute_error: 0.2974
# Epoch 69/120
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0517 - mean_absolute_error: 0.1601 - val_loss: 0.1987 - val_mean_absolute_error: 0.3003
# Epoch 70/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0501 - mean_absolute_error: 0.1576 - val_loss: 0.1984 - val_mean_absolute_error: 0.2978
# Epoch 71/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0526 - mean_absolute_error: 0.1610 - val_loss: 0.2045 - val_mean_absolute_error: 0.3070
# Epoch 72/120
# 3825/3825 [==============================] - 0s 29us/step - loss: 0.0510 - mean_absolute_error: 0.1597 - val_loss: 0.1973 - val_mean_absolute_error: 0.2987
# Epoch 73/120
# 3825/3825 [==============================] - 0s 17us/step - loss: 0.0485 - mean_absolute_error: 0.1561 - val_loss: 0.1951 - val_mean_absolute_error: 0.2956
# Epoch 74/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0471 - mean_absolute_error: 0.1528 - val_loss: 0.1954 - val_mean_absolute_error: 0.2956
# Epoch 75/120
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0460 - mean_absolute_error: 0.1496 - val_loss: 0.1945 - val_mean_absolute_error: 0.2950
# Epoch 76/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0454 - mean_absolute_error: 0.1495 - val_loss: 0.1968 - val_mean_absolute_error: 0.2947
# Epoch 77/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0446 - mean_absolute_error: 0.1467 - val_loss: 0.1947 - val_mean_absolute_error: 0.2946
# Epoch 78/120
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0443 - mean_absolute_error: 0.1484 - val_loss: 0.1973 - val_mean_absolute_error: 0.2979
# Epoch 79/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0436 - mean_absolute_error: 0.1466 - val_loss: 0.1934 - val_mean_absolute_error: 0.2923
# Epoch 80/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0425 - mean_absolute_error: 0.1437 - val_loss: 0.1969 - val_mean_absolute_error: 0.2957
# Epoch 81/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0418 - mean_absolute_error: 0.1430 - val_loss: 0.1918 - val_mean_absolute_error: 0.2905
# Epoch 82/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0412 - mean_absolute_error: 0.1412 - val_loss: 0.1947 - val_mean_absolute_error: 0.2934
# Epoch 83/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0410 - mean_absolute_error: 0.1415 - val_loss: 0.1919 - val_mean_absolute_error: 0.2905
# Epoch 84/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0403 - mean_absolute_error: 0.1394 - val_loss: 0.1945 - val_mean_absolute_error: 0.2930
# Epoch 85/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0405 - mean_absolute_error: 0.1397 - val_loss: 0.1930 - val_mean_absolute_error: 0.2907
# Epoch 86/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0408 - mean_absolute_error: 0.1405 - val_loss: 0.1921 - val_mean_absolute_error: 0.2897
# Epoch 87/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0385 - mean_absolute_error: 0.1369 - val_loss: 0.1934 - val_mean_absolute_error: 0.2919
# Epoch 88/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0385 - mean_absolute_error: 0.1363 - val_loss: 0.1914 - val_mean_absolute_error: 0.2899
# Epoch 89/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0378 - mean_absolute_error: 0.1350 - val_loss: 0.1939 - val_mean_absolute_error: 0.2906
# Epoch 90/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0375 - mean_absolute_error: 0.1344 - val_loss: 0.1927 - val_mean_absolute_error: 0.2895
# Epoch 91/120
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0361 - mean_absolute_error: 0.1323 - val_loss: 0.1907 - val_mean_absolute_error: 0.2885
# Epoch 92/120
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0366 - mean_absolute_error: 0.1324 - val_loss: 0.1925 - val_mean_absolute_error: 0.2895
# Epoch 93/120
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0360 - mean_absolute_error: 0.1322 - val_loss: 0.1907 - val_mean_absolute_error: 0.2886
# Epoch 94/120
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0349 - mean_absolute_error: 0.1289 - val_loss: 0.1916 - val_mean_absolute_error: 0.2878
# Epoch 95/120
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0342 - mean_absolute_error: 0.1281 - val_loss: 0.1916 - val_mean_absolute_error: 0.2883
# Epoch 96/120
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0342 - mean_absolute_error: 0.1288 - val_loss: 0.1914 - val_mean_absolute_error: 0.2880
# Epoch 97/120
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0335 - mean_absolute_error: 0.1272 - val_loss: 0.1904 - val_mean_absolute_error: 0.2861
# Epoch 98/120
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0336 - mean_absolute_error: 0.1262 - val_loss: 0.1918 - val_mean_absolute_error: 0.2880
# Epoch 99/120
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0341 - mean_absolute_error: 0.1284 - val_loss: 0.1915 - val_mean_absolute_error: 0.2876
# Epoch 100/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0336 - mean_absolute_error: 0.1271 - val_loss: 0.1913 - val_mean_absolute_error: 0.2857
# Epoch 101/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0323 - mean_absolute_error: 0.1239 - val_loss: 0.1903 - val_mean_absolute_error: 0.2866
# Epoch 102/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.0315 - mean_absolute_error: 0.1220 - val_loss: 0.1932 - val_mean_absolute_error: 0.2880
# Epoch 103/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0317 - mean_absolute_error: 0.1231 - val_loss: 0.1895 - val_mean_absolute_error: 0.2849
# Epoch 104/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0313 - mean_absolute_error: 0.1217 - val_loss: 0.1920 - val_mean_absolute_error: 0.2862
# Epoch 105/120
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0309 - mean_absolute_error: 0.1219 - val_loss: 0.1908 - val_mean_absolute_error: 0.2875
# Epoch 106/120
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0312 - mean_absolute_error: 0.1231 - val_loss: 0.1938 - val_mean_absolute_error: 0.2888
# Epoch 107/120
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0310 - mean_absolute_error: 0.1217 - val_loss: 0.1894 - val_mean_absolute_error: 0.2835
# Epoch 108/120
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0297 - mean_absolute_error: 0.1190 - val_loss: 0.1908 - val_mean_absolute_error: 0.2867
# Epoch 109/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0296 - mean_absolute_error: 0.1186 - val_loss: 0.1909 - val_mean_absolute_error: 0.2861
# Epoch 110/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0304 - mean_absolute_error: 0.1195 - val_loss: 0.1912 - val_mean_absolute_error: 0.2845
# Epoch 111/120
# 3825/3825 [==============================] - 0s 17us/step - loss: 0.0302 - mean_absolute_error: 0.1200 - val_loss: 0.1900 - val_mean_absolute_error: 0.2838
# Epoch 112/120
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0287 - mean_absolute_error: 0.1156 - val_loss: 0.1902 - val_mean_absolute_error: 0.2834
# Epoch 113/120
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0285 - mean_absolute_error: 0.1161 - val_loss: 0.1915 - val_mean_absolute_error: 0.2851
# Epoch 114/120
# 3825/3825 [==============================] - 0s 10us/step - loss: 0.0277 - mean_absolute_error: 0.1133 - val_loss: 0.1906 - val_mean_absolute_error: 0.2831
# Epoch 115/120
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0279 - mean_absolute_error: 0.1148 - val_loss: 0.1901 - val_mean_absolute_error: 0.2833
# Epoch 116/120
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0271 - mean_absolute_error: 0.1118 - val_loss: 0.1902 - val_mean_absolute_error: 0.2827
# Epoch 117/120
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0271 - mean_absolute_error: 0.1131 - val_loss: 0.1907 - val_mean_absolute_error: 0.2831
# Epoch 118/120
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0266 - mean_absolute_error: 0.1107 - val_loss: 0.1912 - val_mean_absolute_error: 0.2837
# Epoch 119/120
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0271 - mean_absolute_error: 0.1127 - val_loss: 0.1900 - val_mean_absolute_error: 0.2830
# Epoch 120/120
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0267 - mean_absolute_error: 0.1115 - val_loss: 0.1913 - val_mean_absolute_error: 0.2839

# %%
preds = model.predict(X_test_sc)  # generate predictions on validation data
preds  # preview predictions
# Out:
# array([[4.783742  ],
#        [1.5076814 ],
#        [0.8985023 ],
#        ...,
#        [0.01715533],
#        [1.9097741 ],
#        [0.7162018 ]], dtype=float32)

# %%
# Save training data loss and validation data loss as variables to plot:
train_loss = history.history['loss']     # 'loss' = mean squared error of training data
test_loss = history.history['val_loss']  # 'val_loss' = mean squared error of validation data

# Plot training and testing loss for the FFNN model:
plt.figure(figsize=(15, 10))
plt.plot(train_loss, label='Training loss', color='navy')
plt.plot(test_loss, label='Testing loss', color='skyblue')
plt.legend();

# Save figure as a PNG file:
plt.savefig('../../images/FFNN_fantasy_training_vs_testing_loss_function_2018.png')

# %%
# Assign predicted fantasy points to validation data as a new column:
X_test['Predicted_FP'] = preds
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Assign true fantasy points to validation data as a new column:
X_test['FantasyPoints'] = y_test
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
X_test.head()  # preview first 5 rows of validation data
# Now, predicted fantasy points per week can be visually compared to true values and all other data columns.
# Out:
#              Rank            Name Position  Week  PassingYards  \
# Date
# 2018-12-09  140.0  Donte Moncrief       WR    14           0.0
# 2018-12-02  214.0     Zach Pascal       WR    13           0.0
# 2018-09-23  245.0    Kenyan Drake       RB     3           0.0
# 2018-12-30   64.0       Rod Smith       RB    17           0.0
# 2018-09-09   80.0    Adam Thielen       WR     1           0.0
#
#             PassingTouchdowns  PassingInterceptions  RushingYards  \
# Date
# 2018-12-09                0.0                   0.0           0.0
# 2018-12-02                0.0                   0.0           2.0
# 2018-09-23                0.0                   0.0           3.0
# 2018-12-30                0.0                   0.0          35.0
# 2018-09-09                0.0                   0.0           0.0
#
#             RushingTouchdowns  Receptions  ...  Opponent_OAK  Opponent_PHI  \
# Date                                       ...
# 2018-12-09                0.0         5.0  ...           0.0           0.0
# 2018-12-02                0.0         1.0  ...           0.0           0.0
# 2018-09-23                0.0         2.0  ...           1.0           0.0
# 2018-12-30                1.0         2.0  ...           0.0           0.0
# 2018-09-09                0.0         6.0  ...           0.0           0.0
#
#             Opponent_PIT  Opponent_SEA  Opponent_SF  Opponent_TB  \
# Date
# 2018-12-09           0.0           0.0          0.0          0.0
# 2018-12-02           0.0           0.0          0.0          0.0
# 2018-09-23           0.0           0.0          0.0          0.0
# 2018-12-30           0.0           0.0          0.0          0.0
# 2018-09-09           0.0           0.0          1.0          0.0
#
#             Opponent_TEN  Opponent_WAS  Predicted_FP  FantasyPoints
# Date
# 2018-12-09           1.0           0.0      4.783742            4.7
# 2018-12-02           0.0           0.0      1.507681            1.8
# 2018-09-23           0.0           0.0      0.898502            1.0
# 2018-12-30           0.0           0.0     12.054936           10.9
# 2018-09-09           0.0           0.0      9.784949           10.2
#
# [5 rows x 80 columns]

# %%
# Calculate and display validation data MSE and RMSE:
test_mse = mean_squared_error(preds, y_test)
print('MSE = ', test_mse)
print('RMSE = ', np.sqrt(test_mse))
# Out:
# MSE =  0.19134102249834112
# RMSE =  0.437425447931806

# %%
# Calculate and display training data MSE and RMSE:
train_preds = model.predict(X_train_sc)
train_mse = mean_squared_error(train_preds, y_train)
print('MSE = ', train_mse)
print('RMSE = ', np.sqrt(train_mse))
# Out:
# MSE =  0.024463112659092262
# RMSE =  0.156406881751067
