# %%
# DataFrame manipulation libraries:
import pandas as pd
import numpy as np
# import props as p

# Visualization libraries:
import matplotlib.pyplot as plt
import seaborn as sns

# Gaussian clustering libraries:
from sklearn.mixture import GaussianMixture
from matplotlib import cm

# %matplotlib inline

# %%
o_df = pd.read_csv('../../clean_data/top_overall_offensive_player_data.csv')

# %%
o_df.head()
# Out:
#    Rank                Name Team Position  Played  PassingYards  \
# 0     1     Patrick Mahomes   KC       QB      16          5097
# 1     2           Matt Ryan  ATL       QB      16          4924
# 2     3  Ben Roethlisberger  PIT       QB      16          5129
# 3     4      Deshaun Watson  HOU       QB      16          4165
# 4     5         Andrew Luck  IND       QB      16          4593
#
#    PassingTouchdowns  PassingInterceptions  RushingYards  RushingTouchdowns  \
# 0                 50                    12           272                  2
# 1                 35                     7           125                  3
# 2                 34                    16            98                  3
# 3                 26                     9           551                  5
# 4                 39                    15           148                  0
#
#    Receptions  ReceivingYards  ReceivingTouchdowns  FumblesLost  \
# 0           0               0                    0            2
# 1           1               5                    1            5
# 2           1              -1                    0            2
# 3           0               0                    0            3
# 4           1               4                    0            1
#
#    FantasyPointsPerGame  FantasyPoints  Year
# 0                  26.1         417.08  2018
# 1                  22.1         353.96  2018
# 2                  21.3         340.86  2018
# 3                  20.7         331.70  2018
# 4                  20.4         326.92  2018

# %%
o_df['Position'].value_counts()
# Out:
# WR    476
# RB    340
# TE    187
# QB    184
# FB     13
# Name: Position, dtype: int64

# %%
def color_positions(pos):
    try:
        if pos == 'WR':
            return 'red'
        if pos == 'RB':
            return 'blue'
        if pos == 'TE':
            return 'orange'
        if pos == 'QB':
            return 'green'
        if pos == 'FB':
            return 'yellow'
        
        return 'black'
    
    except:
        return 'black'

# %%
plt.figure(figsize = (20, 10))

plt.scatter(o_df['Rank'], o_df['FantasyPoints'], 
            c = o_df['Position'].apply(color_positions))

plt.title('Fantasy Points Per Season', fontsize=18)
plt.ylabel('Fantasy Points', fontsize=18)
plt.xlabel('Player Rank', fontsize=18)
plt.xticks(np.arange(0, 301, step=30), size=14)
plt.yticks(np.arange(0, 451, step=50), size=14)
plt.savefig('../../images/initial_clustering_2015_2018.png')
plt.show();

# %%
clusters = 10
g_mix = GaussianMixture(n_components = clusters, random_state = 42)

# %%
X = o_df[['FantasyPoints']]
g_mix.fit(X)
rank_cluster = g_mix.predict(X)

# %%
plt.figure(figsize = (20, 10))

plt.scatter(o_df['Rank'], o_df['FantasyPoints'], 
            c = [cm.Spectral(rank/clusters) for rank in rank_cluster])

plt.title('Fantasy Points Per Season; 1-Dimensional Gaussian Clusters', fontsize=18)
plt.ylabel('Fantasy Points', fontsize=18)
plt.xlabel('Player Rank', fontsize=18)
plt.xticks(np.arange(0, 301, step=30), size=14)
plt.yticks(np.arange(0, 451, step=50), size=14)
plt.savefig('../../images/adjusted_Gaussian_clustering_2015_2018.png')
plt.show();

# %%
o_df.shape
# Out:
# (1200, 17)

# %%
plt.figure(figsize = (20, 10))

plt.plot([o_df.loc[0]['Rank'], o_df.loc[299]['Rank']], 
         [o_df.loc[0]['FantasyPoints'], o_df.loc[299]['FantasyPoints']], color = 'black')

plt.scatter(o_df['Rank'], o_df['FantasyPoints'], 
            c = [cm.Spectral(rank/clusters) for rank in rank_cluster])

plt.title('Fantasy Points Per Season', fontsize=18)
plt.ylabel('Fantasy Points', fontsize=18)
plt.xlabel('Player Rank', fontsize=18)
plt.xticks(np.arange(0, 301, step=30), size=14)
plt.yticks(np.arange(0, 451, step=50), size=14)

plt.savefig('../../images/adjusted_Gaussian_clustering_2015_2018_line_of_best_fit.png')
plt.show();

# %%
# estimate = best_rank - worst_rank
# vals = o_df.loc[:299][['Rank', 'FantasyPoints']] - worst_rank

# Scale by the player's adjusted Gaussian rank using dot product:
# c = np.dot(vals, estimate) / np.dot(estimate, estimate)

# %%
g_mix.fit(o_df[['Rank', 'FantasyPoints']])
rank_2d_cluster = g_mix.predict(o_df[['Rank', 'FantasyPoints']])

# %%
o_df['1D_Cluster'] = rank_cluster
o_df['2D_Cluster'] = rank_2d_cluster

# %%
plt.figure(figsize = (20, 10))

plt.scatter(o_df['Rank'], o_df['FantasyPoints'], 
            c = [cm.Spectral(rank/clusters) for rank in rank_2d_cluster])

plt.title('Fantasy Points Per Season; 2-Dimensional Gaussian Clusters', fontsize=18)
plt.ylabel('Fantasy Points', fontsize=18)
plt.xlabel('Player Rank', fontsize=18)
plt.xticks(np.arange(0, 301, step=30), size=14)
plt.yticks(np.arange(0, 451, step=50), size=14)
plt.savefig('../../images/adjusted_2D_Gaussian_clustering_2015_2018.png')
plt.show();

# %%
o_df['1D_Cluster'].value_counts()
# Out:
# 6    235
# 7    214
# 0    188
# 2    156
# 4    143
# 5    100
# 1     61
# 8     47
# 3     42
# 9     14
# Name: 1D_Cluster, dtype: int64

# %%
o_df['2D_Cluster'].value_counts()
# Out:
# 4    206
# 9    186
# 5    172
# 2    151
# 8    115
# 1    115
# 0     92
# 7     75
# 3     70
# 6     18
# Name: 2D_Cluster, dtype: int64

# %%
# o_df[o_df['Name'] == 'Ezekiel Elliott']

# %%
# o_df[o_df['Name'] == 'Tyreek Hill']

# %%
# o_df[o_df['Rank'] == 1]

# %%
# o_df[o_df['Rank'] == 2]

# %%
# o_df[o_df['Rank'] <= 10]

# %%
# o_df[o_df['1D_Cluster'] == 0]

# %%
# o_df[o_df['1D_Cluster'] == 1]

# %%
# o_df[o_df['2D_Cluster'] == 0]

# %%
# o_df[o_df['2D_Cluster'] == 1]

# %%
# o_df.groupby('2D_Cluster')[['FantasyPoints']].mean()

# %%
o_df.groupby('2D_Cluster')[['FantasyPoints']].agg(['mean', 'std'])
# Out:
#            FantasyPoints
#                     mean        std
# 2D_Cluster
# 0              45.077391   3.871322
# 1             158.545043  11.564859
# 2              75.143974   6.790313
# 3             269.898571  22.390322
# 4              32.576699   4.197499
# 5             120.614419  11.567470
# 6             338.058889  33.109629
# 7             205.557867  14.955699
# 8              94.782522   6.055156
# 9              57.562151   8.101073

# %%
o_df.groupby('1D_Cluster')[['FantasyPoints']].agg(['mean', 'std'])
# Out:
#            FantasyPoints
#                     mean        std
# 1D_Cluster
# 0              51.066809   5.428683
# 1             200.275410  11.503589
# 2              98.097500   7.782793
# 3             288.099048  14.227698
# 4             126.865734   9.320301
# 5             160.701600   9.415297
# 6              33.527915   4.695354
# 7              72.881869   6.955729
# 8             242.160000  13.169115
# 9             349.598571  27.567934

# %%
o_df.groupby('1D_Cluster')[['Rank']].agg(['mean', 'std'])
# Out:
#                   Rank
#                   mean        std
# 1D_Cluster
# 0           218.143617  14.556385
# 1            34.213115   5.910766
# 2           121.865385  12.323639
# 3             9.738095   3.895335
# 4            84.244755  11.331259
# 5            54.020000   8.691084
# 6           270.744681  17.335636
# 7           167.836449  16.428716
# 8            20.297872   4.736146
# 9             2.428571   1.283881

# %%
o_df.groupby('2D_Cluster')[['Rank']].agg(['mean', 'std'])
# Out:
#                   Rank
#                   mean        std
# 2D_Cluster
# 0           236.989130  10.206112
# 1            56.095652  11.036601
# 2           160.476821  13.655199
# 3            13.828571   5.568991
# 4           274.033981  15.782788
# 5            90.982558  14.293692
# 6             3.166667   1.653872
# 7            32.653333   7.026001
# 8           127.878261  10.101370
# 9           202.854839  15.708335

# %%
# o_df.groupby('Rank')[['FantasyPoints']].agg(['mean', 'std'])

# %%
######

# %%
# o_18 = pd.read_csv('../../clean_data/player_weekly_performance_2018.csv')
o_18 = pd.read_csv('../../raw_data/top_nfl_players/overall/offense/o_stat_best_18.csv')
o_17 = pd.read_csv('../../raw_data/top_nfl_players/overall/offense/o_stat_best_17.csv')
o_16 = pd.read_csv('../../raw_data/top_nfl_players/overall/offense/o_stat_best_16.csv')
o_15 = pd.read_csv('../../raw_data/top_nfl_players/overall/offense/o_stat_best_15.csv')

# %%
o_18.head()
# Out:
#    Rank                Name Team Position  Played  PassingYards  \
# 0     1     Patrick Mahomes   KC       QB      16          5097
# 1     2           Matt Ryan  ATL       QB      16          4924
# 2     3  Ben Roethlisberger  PIT       QB      16          5129
# 3     4      Deshaun Watson  HOU       QB      16          4165
# 4     5         Andrew Luck  IND       QB      16          4593
#
#    PassingTouchdowns  PassingInterceptions  RushingYards  RushingTouchdowns  \
# 0                 50                    12           272                  2
# 1                 35                     7           125                  3
# 2                 34                    16            98                  3
# 3                 26                     9           551                  5
# 4                 39                    15           148                  0
#
#    Receptions  ReceivingYards  ReceivingTouchdowns  FumblesLost  \
# 0           0               0                    0            2
# 1           1               5                    1            5
# 2           1              -1                    0            2
# 3           0               0                    0            3
# 4           1               4                    0            1
#
#    FantasyPointsPerGame  FantasyPoints
# 0                  26.1         417.08
# 1                  22.1         353.96
# 2                  21.3         340.86
# 3                  20.7         331.70
# 4                  20.4         326.92

# %%
plt.figure(figsize = (20, 10))

plt.scatter(o_18['Rank'], o_18['FantasyPoints'], 
            c = o_18['Position'].apply(color_positions))

plt.title('Fantasy Points Per Season', fontsize=18)
plt.ylabel('Fantasy Points', fontsize=18)
plt.xlabel('Player Rank', fontsize=18)
plt.xticks(np.arange(0, 301, step=30), size=14)
plt.yticks(np.arange(0, 401, step=50), size=14)
plt.savefig('../../images/initial_Gaussian_clustering_2018.png')
plt.show();

# %%
clusters = 10
g_mix = GaussianMixture(n_components = clusters, random_state = 42)
X = o_18[['FantasyPoints']]
g_mix.fit(X)
rank_cluster = g_mix.predict(X)

# %%
plt.figure(figsize = (20, 10))

plt.scatter(o_18['Rank'], o_18['FantasyPoints'], 
            c = [cm.Spectral(rank/clusters) for rank in rank_cluster])

plt.title('Overall Fantasy Points Per Player 2018; 1-Dimensional Gaussian Clusters', fontsize=18)
plt.ylabel('Fantasy Points', fontsize=18)
plt.xlabel('Player Rank', fontsize=18)
plt.xticks(np.arange(0, 301, step=30), size=14)
plt.yticks(np.arange(0, 401, step=50), size=14)
plt.savefig('../../images/adjusted_1d_Gaussian_clustering_2018.png')
plt.show();

# %%
g_mix.fit(o_18[['Rank', 'FantasyPoints']])
rank_2d_cluster = g_mix.predict(o_18[['Rank', 'FantasyPoints']])
o_18['1D_Cluster'] = rank_cluster
o_18['2D_Cluster'] = rank_2d_cluster

# %%
plt.figure(figsize = (20, 10))

plt.scatter(o_18['Rank'], o_18['FantasyPoints'], 
            c = [cm.Spectral(rank/clusters) for rank in rank_2d_cluster])

plt.title('Fantasy Points By Rank of 2018 Season; 2-Dimensional Gaussian Clusters', fontsize=18)
plt.ylabel('Fantasy Points', fontsize=18)
plt.xlabel('Player Rank', fontsize=18)
plt.xticks(np.arange(0, 301, step=30), size=14)
plt.yticks(np.arange(0, 401, step=50), size=14)
plt.savefig('../../images/adjusted_2D_Gaussian_clustering_2018.png')
plt.show();

# %%
o_18.head()
# Out:
#    Rank                Name Team Position  Played  PassingYards  \
# 0     1     Patrick Mahomes   KC       QB      16          5097
# 1     2           Matt Ryan  ATL       QB      16          4924
# 2     3  Ben Roethlisberger  PIT       QB      16          5129
# 3     4      Deshaun Watson  HOU       QB      16          4165
# 4     5         Andrew Luck  IND       QB      16          4593
#
#    PassingTouchdowns  PassingInterceptions  RushingYards  RushingTouchdowns  \
# 0                 50                    12           272                  2
# 1                 35                     7           125                  3
# 2                 34                    16            98                  3
# 3                 26                     9           551                  5
# 4                 39                    15           148                  0
#
#    Receptions  ReceivingYards  ReceivingTouchdowns  FumblesLost  \
# 0           0               0                    0            2
# 1           1               5                    1            5
# 2           1              -1                    0            2
# 3           0               0                    0            3
# 4           1               4                    0            1
#
#    FantasyPointsPerGame  FantasyPoints  1D_Cluster  2D_Cluster
# 0                  26.1         417.08           6           9
# 1                  22.1         353.96           1           9
# 2                  21.3         340.86           1           2
# 3                  20.7         331.70           1           2
# 4                  20.4         326.92           1           2

# %%
o_18[o_18['1D_Cluster'] == 6]
# Out:
#    Rank             Name Team Position  Played  PassingYards  \
# 0     1  Patrick Mahomes   KC       QB      16          5097
#
#    PassingTouchdowns  PassingInterceptions  RushingYards  RushingTouchdowns  \
# 0                 50                    12           272                  2
#
#    Receptions  ReceivingYards  ReceivingTouchdowns  FumblesLost  \
# 0           0               0                    0            2
#
#    FantasyPointsPerGame  FantasyPoints  1D_Cluster  2D_Cluster
# 0                  26.1         417.08           6           9

# %%
o_18['1D_Cluster'].value_counts()
# Out:
# 4    60
# 2    57
# 7    56
# 0    38
# 5    25
# 3    22
# 8    19
# 1    19
# 9     3
# 6     1
# Name: 1D_Cluster, dtype: int64

# %%
o_18['2D_Cluster'].value_counts()
# Out:
# 1    52
# 5    49
# 7    38
# 0    38
# 3    33
# 6    27
# 2    21
# 8    20
# 4    20
# 9     2
# Name: 2D_Cluster, dtype: int64

# %%
o_18.groupby('1D_Cluster')[['FantasyPoints']].agg(['mean', 'std'])
# Out:
#            FantasyPoints
#                     mean        std
# 1D_Cluster
# 0             106.376316   8.957398
# 1             298.392632  26.885755
# 2              53.672281   6.826274
# 3             164.560909   6.473540
# 4              35.093000   4.454817
# 5             202.088000  14.157380
# 6             417.080000        NaN
# 7              79.671786   7.683837
# 8             136.258947   6.615583
# 9             240.353333   0.564388

# %%
o_18.groupby('2D_Cluster')[['FantasyPoints']].agg(['mean', 'std'])
# Out:
#            FantasyPoints
#                     mean        std
# 2D_Cluster
# 0             125.194737  12.675513
# 1              44.971154   5.060553
# 2             287.455238  29.595283
# 3              70.850909   4.290653
# 4             163.565000   5.901992
# 5              90.788980   7.437668
# 6             200.045926  15.464291
# 7              32.192105   2.212513
# 8              57.590000   4.643377
# 9             385.520000  44.632580

# %%
o_18.groupby('1D_Cluster')[['Rank']].agg(['mean', 'std'])
# Out:
#                   Rank
#                   mean        std
# 1D_Cluster
# 0           108.447368  11.073946
# 1            11.000000   5.627314
# 2           211.929825  16.602345
# 3            59.454545   6.500749
# 4           270.383333  17.404550
# 5            36.000000   7.359801
# 6             1.000000        NaN
# 7           155.428571  16.299311
# 8            79.947368   5.631989
# 9            22.000000   1.000000

# %%
o_18.groupby('2D_Cluster')[['Rank']].agg(['mean', 'std'])
# Out:
#                   Rank
#                   mean        std
# 2D_Cluster
# 0            89.473684  11.137317
# 1           235.769231  16.373838
# 2            13.000000   6.204837
# 3           173.909091   9.767176
# 4            60.350000   6.115339
# 5           132.938776  14.327142
# 6            37.074074   8.061904
# 7           281.315789  11.104188
# 8           202.200000   8.300919
# 9             1.500000   0.707107

# %%
def gauss_2d_plotter(df, col_1, col_2, num_clusters, is_year = True):
    
    # Get the season year of the DataFrame:
    try:
        year = df['Year'].unique()
    except:
        is_year = False
        
    # Instantiate, fit, and predict Gaussian Mix Model based on function parameters:
    g_mix = GaussianMixture(n_components = num_clusters, random_state = 42)
    g_mix.fit(df[[col_1, col_2]])
    g_mix_cluster = g_mix.predict(df[[col_1, col_2]])
    
    # Plot the clusters:
    plt.figure(figsize = (20, 10))
    plt.scatter(df[col_1], df[col_2], c = [cm.rainbow(clust/num_clusters) for clust in g_mix_cluster])
    
    # Create plot title:
    if is_year:
        chart_title = (f'{col_1} By {col_2} of {year} Season; 2D Gaussian Clustering'.format(col_1, col_2, year))
    else:
        chart_title = (f'{col_1} By {col_2}; 2D Gaussian Clustering'.format(col_1, col_2))
        
    plt.title(chart_title, fontsize=18)
    
    # Add x and y axes labels:
    plt.ylabel(col_1, fontsize=18)
    plt.xlabel(col_2, fontsize=18)
    
    # Customize xticks and yticks:
    plt.xticks(np.arange(0, 301, step=30), size=14)
    plt.yticks(np.arange(0, 451, step=50), size=14)
    
    # Display the plot of Gaussian 2D clusters:
    plt.show();

# %%
gauss_2d_plotter(o_df, 'Rank', 'FantasyPoints', 10)

# %%
gauss_2d_plotter(o_18, 'Rank', 'FantasyPoints', 10)

# %%
gauss_2d_plotter(o_17, 'Rank', 'FantasyPoints', 10)

# %%
gauss_2d_plotter(o_16, 'Rank', 'FantasyPoints', 10)

# %%
gauss_2d_plotter(o_15, 'Rank', 'FantasyPoints', 10)
