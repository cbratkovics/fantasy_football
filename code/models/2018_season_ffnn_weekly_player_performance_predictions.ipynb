# %%
# DataFrame manipulation libraries:
import pandas as pd
import numpy as np

# Visualization libraries:
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Evaluation and processing libraries:
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Keras libraries:
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, Dropout, GRU
from keras.optimizers import Adam
from keras.preprocessing.sequence import TimeseriesGenerator
# Out:
# Using TensorFlow backend.

# %%
# Load in CSV data of top player performance per week in the 2015, 2016, 2017, and 2018 NFL seasons:
df = pd.read_csv('../../clean_data/player_weekly_performance_2018.csv')
df.head()  # preview first 5 rows of dataframe
# Out:
#    Rank  PlayerID              Name Team Position  Week Opponent  \
# 0     1      8283  Ryan Fitzpatrick   TB       QB     1       NO
# 1     2     18878      Alvin Kamara   NO       RB     1       TB
# 2     3      7242        Drew Brees   NO       QB     1       TB
# 3     4     18082       Tyreek Hill   KC       WR     1      LAC
# 4     5     18983      James Conner  PIT       RB     1      CLE
#
#    PassingYards  PassingTouchdowns  PassingInterceptions  RushingYards  \
# 0           417                  4                     0            36
# 1             0                  0                     0            29
# 2           439                  3                     0             0
# 3             0                  0                     0             4
# 4             0                  0                     0           135
#
#    RushingTouchdowns  Receptions  ReceivingYards  ReceivingTouchdowns  \
# 0                  1           0               0                    0
# 1                  2           9             112                    1
# 2                  0           0               0                    0
# 3                  0           7             169                    2
# 4                  2           5              57                    0
#
#    FumblesLost  FantasyPoints        Date  Year
# 0            0          42.28  2018-09-09  2018
# 1            0          34.10  2018-09-09  2018
# 2            0          31.56  2018-09-09  2018
# 3            0          29.30  2018-09-09  2018
# 4            1          29.20  2018-09-09  2018

# %%
df['Date'] = pd.to_datetime(df['Date'], format = '%Y-%m-%d') # Convert 'Date' feature into a Pandas datetime object
df.dtypes  # examine data types of features
# Out:
# Rank                             int64
# PlayerID                         int64
# Name                            object
# Team                            object
# Position                        object
# Week                             int64
# Opponent                        object
# PassingYards                     int64
# PassingTouchdowns                int64
# PassingInterceptions             int64
# RushingYards                     int64
# RushingTouchdowns                int64
# Receptions                       int64
# ReceivingYards                   int64
# ReceivingTouchdowns              int64
# FumblesLost                      int64
# FantasyPoints                  float64
# Date                    datetime64[ns]
# Year                             int64
# dtype: object

# %%
df.set_index('Date', inplace=True)  # set Date as the index
df.sort_index(inplace=True)         # sort the dataframe by the Date index
df.head()                           # examine first 5 rows to verify changes
# Out:
#             Rank  PlayerID              Name Team Position  Week Opponent  \
# Date
# 2018-09-09     1      8283  Ryan Fitzpatrick   TB       QB     1       NO
# 2018-09-09     2     18878      Alvin Kamara   NO       RB     1       TB
# 2018-09-09     3      7242        Drew Brees   NO       QB     1       TB
# 2018-09-09     4     18082       Tyreek Hill   KC       WR     1      LAC
# 2018-09-09     5     18983      James Conner  PIT       RB     1      CLE
#
#             PassingYards  PassingTouchdowns  PassingInterceptions  \
# Date
# 2018-09-09           417                  4                     0
# 2018-09-09             0                  0                     0
# 2018-09-09           439                  3                     0
# 2018-09-09             0                  0                     0
# 2018-09-09             0                  0                     0
#
#             RushingYards  RushingTouchdowns  Receptions  ReceivingYards  \
# Date
# 2018-09-09            36                  1           0               0
# 2018-09-09            29                  2           9             112
# 2018-09-09             0                  0           0               0
# 2018-09-09             4                  0           7             169
# 2018-09-09           135                  2           5              57
#
#             ReceivingTouchdowns  FumblesLost  FantasyPoints  Year
# Date
# 2018-09-09                    0            0          42.28  2018
# 2018-09-09                    1            0          34.10  2018
# 2018-09-09                    0            0          31.56  2018
# 2018-09-09                    2            0          29.30  2018
# 2018-09-09                    0            1          29.20  2018

# %%
df.shape  # preview dataframe dimensions; 20,400 rows and 17 columns as features
# Out:
# (5100, 18)

# %%
# Convert player's team, opponent, and position into one-hot encoded variables to use for FFNN:
df_with_dummies = pd.get_dummies(df, columns=['Team', 'Opponent'], drop_first=False)

# Select feature variables to convert into floats; prevents errors when scaling data with StandardScaler:
features = [col for col in df_with_dummies.columns if col not in ['Name', 'Position', 'Week', 'Year', 'PlayerID']]
df_with_dummies[features] = df_with_dummies[features].astype(float)

# Assign X as features to be used for predicting weekly fantasy points per player:
X = df_with_dummies[[col for col in df_with_dummies.columns if col not in ['FantasyPoints', 'PlayerID']]]
# Assign target vector y as weekly fantasy points per player:
y = df_with_dummies['FantasyPoints']

# %%
X.dtypes  # verify that data types have been properly cast
# Out:
# Rank                    float64
# Name                     object
# Position                 object
# Week                      int64
# PassingYards            float64
# PassingTouchdowns       float64
# PassingInterceptions    float64
# RushingYards            float64
# RushingTouchdowns       float64
# Receptions              float64
# ReceivingYards          float64
# ReceivingTouchdowns     float64
# FumblesLost             float64
# Year                      int64
# Team_ARI                float64
# Team_ATL                float64
# Team_BAL                float64
# Team_BUF                float64
# Team_CAR                float64
# Team_CHI                float64
# Team_CIN                float64
# Team_CLE                float64
# Team_DAL                float64
# Team_DEN                float64
# Team_DET                float64
# Team_GB                 float64
# Team_HOU                float64
# Team_IND                float64
# Team_JAX                float64
# Team_KC                 float64
#                          ...
# Opponent_BAL            float64
# Opponent_BUF            float64
# Opponent_CAR            float64
# Opponent_CHI            float64
# Opponent_CIN            float64
# Opponent_CLE            float64
# Opponent_DAL            float64
# Opponent_DEN            float64
# Opponent_DET            float64
# Opponent_GB             float64
# Opponent_HOU            float64
# Opponent_IND            float64
# Opponent_JAX            float64
# Opponent_KC             float64
# Opponent_LAC            float64
# Opponent_LAR            float64
# Opponent_MIA            float64
# Opponent_MIN            float64
# Opponent_NE             float64
# Opponent_NO             float64
# Opponent_NYG            float64
# Opponent_NYJ            float64
# Opponent_OAK            float64
# Opponent_PHI            float64
# Opponent_PIT            float64
# Opponent_SEA            float64
# Opponent_SF             float64
# Opponent_TB             float64
# Opponent_TEN            float64
# Opponent_WAS            float64
# Length: 78, dtype: object

# %%
# Split X and y data into a training set and validation set:
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Scale all columns to use as predictive features using StandardScaler:
ss = StandardScaler()
X_train_sc = ss.fit_transform(X_train.drop(columns = ['Name', 'Position', 'Week', 'Year']))
X_test_sc = ss.transform(X_test.drop(columns = ['Name', 'Position', 'Week', 'Year']))

# %%
X_test_sc[0:5]  # preview first 5 scaled X values in the validation data
# Out:
# array([[-0.07630398, -0.31715918, -0.26621033, -0.20776738, -0.45487011,
#         -0.26056741,  1.15984546,  0.66307007, -0.39695878, -0.19570613,
#         -0.17684817, -0.18074121, -0.19346525, -0.19053746, -0.17367869,
#         -0.17447582, -0.16718097, -0.18151105, -0.18380366, -0.18227804,
#         -0.18831599, -0.17996851, -0.17684817, -0.18151105,  5.89471488,
#         -0.18074121, -0.17684817, -0.16215612, -0.17996851, -0.17841432,
#         -0.19273688, -0.18304223, -0.17684817, -0.17606051, -0.19200614,
#         -0.18151105, -0.17841432, -0.17919289, -0.17447582, -0.17606051,
#         -0.18074121, -0.17367869, -0.18074121, -0.19273688, -0.17367869,
#         -0.17919289, -0.17841432, -0.18456235, -0.18304223, -0.17447582,
#         -0.17763276, -0.17606051, -0.18227804, -0.17919289, -0.19200614,
#         -0.17526974, -0.17526974, -0.18831599, -0.17606051, -0.17126767,
#         -0.17996851, -0.17207467, -0.18074121, -0.16964349, -0.18682237,
#         -0.18380366, -0.18531834, -0.17287832, -0.17996851, -0.17526974,
#         -0.17919289, -0.17526974,  5.3526781 , -0.17684817],
#        [ 0.81502704, -0.31715918, -0.26621033, -0.20776738, -0.37688714,
#         -0.26056741, -0.5215678 , -0.30377122, -0.39695878, -0.19570613,
#         -0.17684817, -0.18074121, -0.19346525, -0.19053746, -0.17367869,
#         -0.17447582, -0.16718097, -0.18151105, -0.18380366, -0.18227804,
#         -0.18831599, -0.17996851, -0.17684817,  5.50930658, -0.16964349,
#         -0.18074121, -0.17684817, -0.16215612, -0.17996851, -0.17841432,
#         -0.19273688, -0.18304223, -0.17684817, -0.17606051, -0.19200614,
#         -0.18151105, -0.17841432, -0.17919289, -0.17447582, -0.17606051,
#         -0.18074121, -0.17367869, -0.18074121, -0.19273688, -0.17367869,
#         -0.17919289, -0.17841432, -0.18456235, -0.18304223, -0.17447582,
#         -0.17763276, -0.17606051, -0.18227804, -0.17919289, -0.19200614,
#         -0.17526974,  5.70549135, -0.18831599, -0.17606051, -0.17126767,
#         -0.17996851, -0.17207467, -0.18074121, -0.16964349, -0.18682237,
#         -0.18380366, -0.18531834, -0.17287832, -0.17996851, -0.17526974,
#         -0.17919289, -0.17526974, -0.18682237, -0.17684817],
#        [ 1.18842246, -0.31715918, -0.26621033, -0.20776738, -0.33789565,
#         -0.26056741, -0.10121448, -0.58446707, -0.39695878, -0.19570613,
#         -0.17684817, -0.18074121, -0.19346525, -0.19053746, -0.17367869,
#         -0.17447582, -0.16718097, -0.18151105, -0.18380366, -0.18227804,
#         -0.18831599, -0.17996851, -0.17684817, -0.18151105, -0.16964349,
#         -0.18074121, -0.17684817, -0.16215612,  5.55652769, -0.17841432,
#         -0.19273688, -0.18304223, -0.17684817, -0.17606051, -0.19200614,
#         -0.18151105, -0.17841432, -0.17919289, -0.17447582, -0.17606051,
#         -0.18074121, -0.17367869, -0.18074121, -0.19273688, -0.17367869,
#         -0.17919289, -0.17841432, -0.18456235, -0.18304223, -0.17447582,
#         -0.17763276, -0.17606051, -0.18227804, -0.17919289, -0.19200614,
#         -0.17526974, -0.17526974, -0.18831599, -0.17606051, -0.17126767,
#         -0.17996851, -0.17207467, -0.18074121, -0.16964349, -0.18682237,
#         -0.18380366,  5.39611992, -0.17287832, -0.17996851, -0.17526974,
#         -0.17919289, -0.17526974, -0.18682237, -0.17684817],
#        [-0.99172503, -0.31715918, -0.26621033, -0.20776738,  0.90983197,
#          2.69691134, -0.10121448, -0.36614807, -0.39695878, -0.19570613,
#         -0.17684817, -0.18074121, -0.19346525, -0.19053746, -0.17367869,
#         -0.17447582, -0.16718097, -0.18151105,  5.4405882 , -0.18227804,
#         -0.18831599, -0.17996851, -0.17684817, -0.18151105, -0.16964349,
#         -0.18074121, -0.17684817, -0.16215612, -0.17996851, -0.17841432,
#         -0.19273688, -0.18304223, -0.17684817, -0.17606051, -0.19200614,
#         -0.18151105, -0.17841432, -0.17919289, -0.17447582, -0.17606051,
#         -0.18074121, -0.17367869, -0.18074121, -0.19273688, -0.17367869,
#         -0.17919289, -0.17841432, -0.18456235, -0.18304223, -0.17447582,
#         -0.17763276, -0.17606051, -0.18227804, -0.17919289, -0.19200614,
#         -0.17526974, -0.17526974, -0.18831599, -0.17606051, -0.17126767,
#         -0.17996851, -0.17207467, -0.18074121, -0.16964349,  5.3526781 ,
#         -0.18380366, -0.18531834, -0.17287832, -0.17996851, -0.17526974,
#         -0.17919289, -0.17526974, -0.18682237, -0.17684817],
#        [-0.79900481, -0.31715918, -0.26621033, -0.20776738, -0.45487011,
#         -0.26056741,  1.58019878,  2.37843364, -0.39695878, -0.19570613,
#         -0.17684817, -0.18074121, -0.19346525, -0.19053746, -0.17367869,
#         -0.17447582, -0.16718097, -0.18151105, -0.18380366, -0.18227804,
#         -0.18831599, -0.17996851, -0.17684817, -0.18151105, -0.16964349,
#         -0.18074121, -0.17684817, -0.16215612, -0.17996851,  5.60493124,
#         -0.19273688, -0.18304223, -0.17684817, -0.17606051, -0.19200614,
#         -0.18151105, -0.17841432, -0.17919289, -0.17447582, -0.17606051,
#         -0.18074121, -0.17367869, -0.18074121, -0.19273688, -0.17367869,
#         -0.17919289, -0.17841432, -0.18456235, -0.18304223, -0.17447582,
#         -0.17763276, -0.17606051, -0.18227804, -0.17919289, -0.19200614,
#         -0.17526974, -0.17526974, -0.18831599, -0.17606051, -0.17126767,
#         -0.17996851, -0.17207467, -0.18074121, -0.16964349, -0.18682237,
#         -0.18380366, -0.18531834, -0.17287832, -0.17996851, -0.17526974,
#          5.58057857, -0.17526974, -0.18682237, -0.17684817]])

# %%
X_test_sc.shape  # check shape of scaled X validation data
# Out:
# (1275, 74)

# %%
# Instantiate and build feed-forward neural network to predict player performance per week:
model = Sequential()                                        # instantiate model
model.add(Dense(74, activation='relu', input_shape=(74,)))  # input layer with 74 neurons
model.add(Dense(74, activation='relu'))                     # first hidden layer with 74 neurons
model.add(Dense(37, activation='relu'))                     # second hidden layer with 37 neurons
model.add(Dense(1))                                         # output layer with 1 neuron; represents predicted points
# Out:
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=15, verbose=1, mode='auto')

# %%
# Compile the FFNN model:
model.compile(loss='mse', optimizer='adam', metrics=['mae'])
# loss function = mean squared error
# optimization function = adam
# evaluation metric = mean absolute error

# %%
# Train the FFNN model using training, error is measured using validation data:
history = model.fit(X_train_sc, y_train, validation_data=(X_test_sc, y_test), epochs=150, 
                    batch_size=256) #, callbacks = [early_stop])
# Out:
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 3825 samples, validate on 1275 samples
# Epoch 1/150
# 3825/3825 [==============================] - 0s 89us/step - loss: 89.1675 - mean_absolute_error: 6.2558 - val_loss: 61.4914 - val_mean_absolute_error: 5.0942
# Epoch 2/150
# 3825/3825 [==============================] - 0s 19us/step - loss: 52.7074 - mean_absolute_error: 5.0683 - val_loss: 37.0221 - val_mean_absolute_error: 4.9124
# Epoch 3/150
# 3825/3825 [==============================] - 0s 23us/step - loss: 33.5290 - mean_absolute_error: 4.8584 - val_loss: 25.2703 - val_mean_absolute_error: 4.3205
# Epoch 4/150
# 3825/3825 [==============================] - 0s 26us/step - loss: 19.4901 - mean_absolute_error: 3.6546 - val_loss: 13.6399 - val_mean_absolute_error: 3.0717
# Epoch 5/150
# 3825/3825 [==============================] - 0s 26us/step - loss: 9.4583 - mean_absolute_error: 2.5087 - val_loss: 6.1760 - val_mean_absolute_error: 1.9831
# Epoch 6/150
# 3825/3825 [==============================] - 0s 22us/step - loss: 3.9052 - mean_absolute_error: 1.5135 - val_loss: 2.8303 - val_mean_absolute_error: 1.1979
# Epoch 7/150
# 3825/3825 [==============================] - 0s 24us/step - loss: 1.9771 - mean_absolute_error: 1.0346 - val_loss: 1.7254 - val_mean_absolute_error: 0.9348
# Epoch 8/150
# 3825/3825 [==============================] - 0s 16us/step - loss: 1.2906 - mean_absolute_error: 0.8500 - val_loss: 1.3172 - val_mean_absolute_error: 0.8391
# Epoch 9/150
# 3825/3825 [==============================] - 0s 16us/step - loss: 1.0117 - mean_absolute_error: 0.7646 - val_loss: 1.0859 - val_mean_absolute_error: 0.7700
# Epoch 10/150
# 3825/3825 [==============================] - 0s 21us/step - loss: 0.8248 - mean_absolute_error: 0.6886 - val_loss: 0.9168 - val_mean_absolute_error: 0.7019
# Epoch 11/150
# 3825/3825 [==============================] - 0s 23us/step - loss: 0.6910 - mean_absolute_error: 0.6280 - val_loss: 0.8024 - val_mean_absolute_error: 0.6546
# Epoch 12/150
# 3825/3825 [==============================] - 0s 19us/step - loss: 0.5921 - mean_absolute_error: 0.5819 - val_loss: 0.7054 - val_mean_absolute_error: 0.6117
# Epoch 13/150
# 3825/3825 [==============================] - 0s 17us/step - loss: 0.5130 - mean_absolute_error: 0.5387 - val_loss: 0.6361 - val_mean_absolute_error: 0.5799
# Epoch 14/150
# 3825/3825 [==============================] - 0s 17us/step - loss: 0.4485 - mean_absolute_error: 0.5031 - val_loss: 0.5758 - val_mean_absolute_error: 0.5501
# Epoch 15/150
# 3825/3825 [==============================] - 0s 19us/step - loss: 0.3971 - mean_absolute_error: 0.4729 - val_loss: 0.5321 - val_mean_absolute_error: 0.5305
# Epoch 16/150
# 3825/3825 [==============================] - 0s 17us/step - loss: 0.3558 - mean_absolute_error: 0.4472 - val_loss: 0.4908 - val_mean_absolute_error: 0.5075
# Epoch 17/150
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.3269 - mean_absolute_error: 0.4265 - val_loss: 0.4543 - val_mean_absolute_error: 0.4903
# Epoch 18/150
# 3825/3825 [==============================] - 0s 20us/step - loss: 0.2981 - mean_absolute_error: 0.4067 - val_loss: 0.4364 - val_mean_absolute_error: 0.4769
# Epoch 19/150
# 3825/3825 [==============================] - 0s 17us/step - loss: 0.2749 - mean_absolute_error: 0.3898 - val_loss: 0.4084 - val_mean_absolute_error: 0.4615
# Epoch 20/150
# 3825/3825 [==============================] - 0s 17us/step - loss: 0.2519 - mean_absolute_error: 0.3726 - val_loss: 0.3858 - val_mean_absolute_error: 0.4458
# Epoch 21/150
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.2315 - mean_absolute_error: 0.3572 - val_loss: 0.3699 - val_mean_absolute_error: 0.4372
# Epoch 22/150
# 3825/3825 [==============================] - 0s 16us/step - loss: 0.2169 - mean_absolute_error: 0.3449 - val_loss: 0.3537 - val_mean_absolute_error: 0.4259
# Epoch 23/150
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.2045 - mean_absolute_error: 0.3346 - val_loss: 0.3480 - val_mean_absolute_error: 0.4215
# Epoch 24/150
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.1938 - mean_absolute_error: 0.3242 - val_loss: 0.3353 - val_mean_absolute_error: 0.4129
# Epoch 25/150
# 3825/3825 [==============================] - 0s 22us/step - loss: 0.1825 - mean_absolute_error: 0.3149 - val_loss: 0.3231 - val_mean_absolute_error: 0.4035
# Epoch 26/150
# 3825/3825 [==============================] - 0s 20us/step - loss: 0.1718 - mean_absolute_error: 0.3053 - val_loss: 0.3127 - val_mean_absolute_error: 0.3970
# Epoch 27/150
# 3825/3825 [==============================] - 0s 19us/step - loss: 0.1624 - mean_absolute_error: 0.2962 - val_loss: 0.3036 - val_mean_absolute_error: 0.3904
# Epoch 28/150
# 3825/3825 [==============================] - 0s 20us/step - loss: 0.1550 - mean_absolute_error: 0.2895 - val_loss: 0.2987 - val_mean_absolute_error: 0.3849
# Epoch 29/150
# 3825/3825 [==============================] - 0s 19us/step - loss: 0.1490 - mean_absolute_error: 0.2828 - val_loss: 0.2904 - val_mean_absolute_error: 0.3798
# Epoch 30/150
# 3825/3825 [==============================] - 0s 21us/step - loss: 0.1414 - mean_absolute_error: 0.2757 - val_loss: 0.2865 - val_mean_absolute_error: 0.3744
# Epoch 31/150
# 3825/3825 [==============================] - 0s 23us/step - loss: 0.1365 - mean_absolute_error: 0.2699 - val_loss: 0.2807 - val_mean_absolute_error: 0.3708
# Epoch 32/150
# 3825/3825 [==============================] - 0s 16us/step - loss: 0.1323 - mean_absolute_error: 0.2646 - val_loss: 0.2869 - val_mean_absolute_error: 0.3750
# Epoch 33/150
# 3825/3825 [==============================] - 0s 18us/step - loss: 0.1284 - mean_absolute_error: 0.2615 - val_loss: 0.2749 - val_mean_absolute_error: 0.3658
# Epoch 34/150
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.1193 - mean_absolute_error: 0.2528 - val_loss: 0.2659 - val_mean_absolute_error: 0.3595
# Epoch 35/150
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.1160 - mean_absolute_error: 0.2485 - val_loss: 0.2631 - val_mean_absolute_error: 0.3561
# Epoch 36/150
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.1111 - mean_absolute_error: 0.2431 - val_loss: 0.2605 - val_mean_absolute_error: 0.3551
# Epoch 37/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.1078 - mean_absolute_error: 0.2389 - val_loss: 0.2583 - val_mean_absolute_error: 0.3510
# Epoch 38/150
# 3825/3825 [==============================] - 0s 18us/step - loss: 0.1058 - mean_absolute_error: 0.2369 - val_loss: 0.2555 - val_mean_absolute_error: 0.3491
# Epoch 39/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.1011 - mean_absolute_error: 0.2308 - val_loss: 0.2500 - val_mean_absolute_error: 0.3458
# Epoch 40/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0966 - mean_absolute_error: 0.2253 - val_loss: 0.2477 - val_mean_absolute_error: 0.3430
# Epoch 41/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0943 - mean_absolute_error: 0.2230 - val_loss: 0.2459 - val_mean_absolute_error: 0.3403
# Epoch 42/150
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0913 - mean_absolute_error: 0.2194 - val_loss: 0.2434 - val_mean_absolute_error: 0.3395
# Epoch 43/150
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0892 - mean_absolute_error: 0.2160 - val_loss: 0.2449 - val_mean_absolute_error: 0.3393
# Epoch 44/150
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.0872 - mean_absolute_error: 0.2148 - val_loss: 0.2394 - val_mean_absolute_error: 0.3361
# Epoch 45/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0839 - mean_absolute_error: 0.2092 - val_loss: 0.2368 - val_mean_absolute_error: 0.3332
# Epoch 46/150
# 3825/3825 [==============================] - 0s 16us/step - loss: 0.0814 - mean_absolute_error: 0.2059 - val_loss: 0.2363 - val_mean_absolute_error: 0.3330
# Epoch 47/150
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0792 - mean_absolute_error: 0.2032 - val_loss: 0.2334 - val_mean_absolute_error: 0.3302
# Epoch 48/150
# 3825/3825 [==============================] - 0s 21us/step - loss: 0.0774 - mean_absolute_error: 0.2009 - val_loss: 0.2306 - val_mean_absolute_error: 0.3279
# Epoch 49/150
# 3825/3825 [==============================] - 0s 22us/step - loss: 0.0753 - mean_absolute_error: 0.1980 - val_loss: 0.2311 - val_mean_absolute_error: 0.3275
# Epoch 50/150
# 3825/3825 [==============================] - 0s 25us/step - loss: 0.0729 - mean_absolute_error: 0.1948 - val_loss: 0.2307 - val_mean_absolute_error: 0.3274
# Epoch 51/150
# 3825/3825 [==============================] - 0s 23us/step - loss: 0.0708 - mean_absolute_error: 0.1914 - val_loss: 0.2289 - val_mean_absolute_error: 0.3246
# Epoch 52/150
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.0692 - mean_absolute_error: 0.1903 - val_loss: 0.2272 - val_mean_absolute_error: 0.3244
# Epoch 53/150
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0686 - mean_absolute_error: 0.1884 - val_loss: 0.2277 - val_mean_absolute_error: 0.3241
# Epoch 54/150
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0669 - mean_absolute_error: 0.1862 - val_loss: 0.2243 - val_mean_absolute_error: 0.3214
# Epoch 55/150
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0651 - mean_absolute_error: 0.1835 - val_loss: 0.2241 - val_mean_absolute_error: 0.3210
# Epoch 56/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0639 - mean_absolute_error: 0.1816 - val_loss: 0.2246 - val_mean_absolute_error: 0.3201
# Epoch 57/150
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0615 - mean_absolute_error: 0.1781 - val_loss: 0.2250 - val_mean_absolute_error: 0.3206
# Epoch 58/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0607 - mean_absolute_error: 0.1770 - val_loss: 0.2209 - val_mean_absolute_error: 0.3189
# Epoch 59/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0599 - mean_absolute_error: 0.1753 - val_loss: 0.2212 - val_mean_absolute_error: 0.3181
# Epoch 60/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0584 - mean_absolute_error: 0.1735 - val_loss: 0.2215 - val_mean_absolute_error: 0.3180
# Epoch 61/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0584 - mean_absolute_error: 0.1721 - val_loss: 0.2196 - val_mean_absolute_error: 0.3163
# Epoch 62/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0563 - mean_absolute_error: 0.1703 - val_loss: 0.2181 - val_mean_absolute_error: 0.3149
# Epoch 63/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0543 - mean_absolute_error: 0.1665 - val_loss: 0.2205 - val_mean_absolute_error: 0.3157
# Epoch 64/150
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0536 - mean_absolute_error: 0.1652 - val_loss: 0.2177 - val_mean_absolute_error: 0.3138
# Epoch 65/150
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0536 - mean_absolute_error: 0.1649 - val_loss: 0.2195 - val_mean_absolute_error: 0.3136
# Epoch 66/150
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0515 - mean_absolute_error: 0.1627 - val_loss: 0.2197 - val_mean_absolute_error: 0.3155
# Epoch 67/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0520 - mean_absolute_error: 0.1627 - val_loss: 0.2156 - val_mean_absolute_error: 0.3121
# Epoch 68/150
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0509 - mean_absolute_error: 0.1600 - val_loss: 0.2146 - val_mean_absolute_error: 0.3115
# Epoch 69/150
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0495 - mean_absolute_error: 0.1574 - val_loss: 0.2161 - val_mean_absolute_error: 0.3109
# Epoch 70/150
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0500 - mean_absolute_error: 0.1591 - val_loss: 0.2155 - val_mean_absolute_error: 0.3108
# Epoch 71/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0480 - mean_absolute_error: 0.1559 - val_loss: 0.2173 - val_mean_absolute_error: 0.3114
# Epoch 72/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0465 - mean_absolute_error: 0.1527 - val_loss: 0.2141 - val_mean_absolute_error: 0.3099
# Epoch 73/150
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0456 - mean_absolute_error: 0.1519 - val_loss: 0.2178 - val_mean_absolute_error: 0.3110
# Epoch 74/150
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.0457 - mean_absolute_error: 0.1522 - val_loss: 0.2140 - val_mean_absolute_error: 0.3099
# Epoch 75/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0444 - mean_absolute_error: 0.1493 - val_loss: 0.2152 - val_mean_absolute_error: 0.3092
# Epoch 76/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0436 - mean_absolute_error: 0.1475 - val_loss: 0.2122 - val_mean_absolute_error: 0.3082
# Epoch 77/150
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0422 - mean_absolute_error: 0.1449 - val_loss: 0.2141 - val_mean_absolute_error: 0.3086
# Epoch 78/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0424 - mean_absolute_error: 0.1462 - val_loss: 0.2186 - val_mean_absolute_error: 0.3095
# Epoch 79/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0420 - mean_absolute_error: 0.1442 - val_loss: 0.2131 - val_mean_absolute_error: 0.3072
# Epoch 80/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0409 - mean_absolute_error: 0.1432 - val_loss: 0.2135 - val_mean_absolute_error: 0.3074
# Epoch 81/150
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0407 - mean_absolute_error: 0.1419 - val_loss: 0.2150 - val_mean_absolute_error: 0.3079
# Epoch 82/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0402 - mean_absolute_error: 0.1413 - val_loss: 0.2128 - val_mean_absolute_error: 0.3064
# Epoch 83/150
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0386 - mean_absolute_error: 0.1379 - val_loss: 0.2127 - val_mean_absolute_error: 0.3047
# Epoch 84/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0388 - mean_absolute_error: 0.1389 - val_loss: 0.2102 - val_mean_absolute_error: 0.3047
# Epoch 85/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0384 - mean_absolute_error: 0.1375 - val_loss: 0.2147 - val_mean_absolute_error: 0.3065
# Epoch 86/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0373 - mean_absolute_error: 0.1363 - val_loss: 0.2121 - val_mean_absolute_error: 0.3050
# Epoch 87/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0373 - mean_absolute_error: 0.1358 - val_loss: 0.2141 - val_mean_absolute_error: 0.3066
# Epoch 88/150
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0365 - mean_absolute_error: 0.1343 - val_loss: 0.2157 - val_mean_absolute_error: 0.3056
# Epoch 89/150
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.0364 - mean_absolute_error: 0.1335 - val_loss: 0.2138 - val_mean_absolute_error: 0.3038
# Epoch 90/150
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.0350 - mean_absolute_error: 0.1315 - val_loss: 0.2110 - val_mean_absolute_error: 0.3040
# Epoch 91/150
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.0349 - mean_absolute_error: 0.1309 - val_loss: 0.2168 - val_mean_absolute_error: 0.3055
# Epoch 92/150
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0345 - mean_absolute_error: 0.1296 - val_loss: 0.2129 - val_mean_absolute_error: 0.3028
# Epoch 93/150
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0340 - mean_absolute_error: 0.1288 - val_loss: 0.2111 - val_mean_absolute_error: 0.3032
# Epoch 94/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0341 - mean_absolute_error: 0.1285 - val_loss: 0.2134 - val_mean_absolute_error: 0.3040
# Epoch 95/150
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0335 - mean_absolute_error: 0.1275 - val_loss: 0.2166 - val_mean_absolute_error: 0.3058
# Epoch 96/150
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0352 - mean_absolute_error: 0.1335 - val_loss: 0.2093 - val_mean_absolute_error: 0.3018
# Epoch 97/150
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.0341 - mean_absolute_error: 0.1299 - val_loss: 0.2170 - val_mean_absolute_error: 0.3056
# Epoch 98/150
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0328 - mean_absolute_error: 0.1259 - val_loss: 0.2170 - val_mean_absolute_error: 0.3051
# Epoch 99/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0322 - mean_absolute_error: 0.1255 - val_loss: 0.2135 - val_mean_absolute_error: 0.3017
# Epoch 100/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0309 - mean_absolute_error: 0.1220 - val_loss: 0.2125 - val_mean_absolute_error: 0.3026
# Epoch 101/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0314 - mean_absolute_error: 0.1236 - val_loss: 0.2132 - val_mean_absolute_error: 0.3012
# Epoch 102/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0304 - mean_absolute_error: 0.1213 - val_loss: 0.2175 - val_mean_absolute_error: 0.3058
# Epoch 103/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0312 - mean_absolute_error: 0.1236 - val_loss: 0.2201 - val_mean_absolute_error: 0.3082
# Epoch 104/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0328 - mean_absolute_error: 0.1285 - val_loss: 0.2115 - val_mean_absolute_error: 0.2998
# Epoch 105/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0300 - mean_absolute_error: 0.1206 - val_loss: 0.2149 - val_mean_absolute_error: 0.3021
# Epoch 106/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0297 - mean_absolute_error: 0.1198 - val_loss: 0.2152 - val_mean_absolute_error: 0.3015
# Epoch 107/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0303 - mean_absolute_error: 0.1225 - val_loss: 0.2150 - val_mean_absolute_error: 0.3031
# Epoch 108/150
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0289 - mean_absolute_error: 0.1179 - val_loss: 0.2100 - val_mean_absolute_error: 0.2985
# Epoch 109/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0281 - mean_absolute_error: 0.1157 - val_loss: 0.2139 - val_mean_absolute_error: 0.3001
# Epoch 110/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0282 - mean_absolute_error: 0.1165 - val_loss: 0.2089 - val_mean_absolute_error: 0.2973
# Epoch 111/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0280 - mean_absolute_error: 0.1149 - val_loss: 0.2135 - val_mean_absolute_error: 0.3001
# Epoch 112/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0275 - mean_absolute_error: 0.1145 - val_loss: 0.2135 - val_mean_absolute_error: 0.3015
# Epoch 113/150
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0268 - mean_absolute_error: 0.1129 - val_loss: 0.2102 - val_mean_absolute_error: 0.2981
# Epoch 114/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0268 - mean_absolute_error: 0.1129 - val_loss: 0.2137 - val_mean_absolute_error: 0.3001
# Epoch 115/150
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0272 - mean_absolute_error: 0.1140 - val_loss: 0.2139 - val_mean_absolute_error: 0.3018
# Epoch 116/150
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0265 - mean_absolute_error: 0.1122 - val_loss: 0.2148 - val_mean_absolute_error: 0.3009
# Epoch 117/150
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0263 - mean_absolute_error: 0.1111 - val_loss: 0.2112 - val_mean_absolute_error: 0.2983
# Epoch 118/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0255 - mean_absolute_error: 0.1091 - val_loss: 0.2128 - val_mean_absolute_error: 0.2988
# Epoch 119/150
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0255 - mean_absolute_error: 0.1092 - val_loss: 0.2100 - val_mean_absolute_error: 0.2979
# Epoch 120/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0253 - mean_absolute_error: 0.1092 - val_loss: 0.2115 - val_mean_absolute_error: 0.2993
# Epoch 121/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0251 - mean_absolute_error: 0.1093 - val_loss: 0.2133 - val_mean_absolute_error: 0.3004
# Epoch 122/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0256 - mean_absolute_error: 0.1093 - val_loss: 0.2149 - val_mean_absolute_error: 0.3006
# Epoch 123/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0252 - mean_absolute_error: 0.1087 - val_loss: 0.2137 - val_mean_absolute_error: 0.2992
# Epoch 124/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0246 - mean_absolute_error: 0.1069 - val_loss: 0.2144 - val_mean_absolute_error: 0.3007
# Epoch 125/150
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0239 - mean_absolute_error: 0.1058 - val_loss: 0.2132 - val_mean_absolute_error: 0.2982
# Epoch 126/150
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0238 - mean_absolute_error: 0.1049 - val_loss: 0.2147 - val_mean_absolute_error: 0.3001
# Epoch 127/150
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0235 - mean_absolute_error: 0.1045 - val_loss: 0.2127 - val_mean_absolute_error: 0.2976
# Epoch 128/150
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0232 - mean_absolute_error: 0.1030 - val_loss: 0.2137 - val_mean_absolute_error: 0.2980
# Epoch 129/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0229 - mean_absolute_error: 0.1026 - val_loss: 0.2113 - val_mean_absolute_error: 0.2964
# Epoch 130/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0230 - mean_absolute_error: 0.1024 - val_loss: 0.2141 - val_mean_absolute_error: 0.2979
# Epoch 131/150
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0232 - mean_absolute_error: 0.1046 - val_loss: 0.2140 - val_mean_absolute_error: 0.2999
# Epoch 132/150
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0229 - mean_absolute_error: 0.1031 - val_loss: 0.2161 - val_mean_absolute_error: 0.2984
# Epoch 133/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0239 - mean_absolute_error: 0.1063 - val_loss: 0.2126 - val_mean_absolute_error: 0.2985
# Epoch 134/150
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0228 - mean_absolute_error: 0.1033 - val_loss: 0.2129 - val_mean_absolute_error: 0.2967
# Epoch 135/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0229 - mean_absolute_error: 0.1028 - val_loss: 0.2152 - val_mean_absolute_error: 0.3008
# Epoch 136/150
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.0231 - mean_absolute_error: 0.1018 - val_loss: 0.2134 - val_mean_absolute_error: 0.2968
# Epoch 137/150
# 3825/3825 [==============================] - 0s 20us/step - loss: 0.0222 - mean_absolute_error: 0.1004 - val_loss: 0.2138 - val_mean_absolute_error: 0.2978
# Epoch 138/150
# 3825/3825 [==============================] - 0s 18us/step - loss: 0.0215 - mean_absolute_error: 0.0991 - val_loss: 0.2163 - val_mean_absolute_error: 0.2999
# Epoch 139/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0211 - mean_absolute_error: 0.0981 - val_loss: 0.2152 - val_mean_absolute_error: 0.2987
# Epoch 140/150
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0213 - mean_absolute_error: 0.0981 - val_loss: 0.2149 - val_mean_absolute_error: 0.2977
# Epoch 141/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0218 - mean_absolute_error: 0.0999 - val_loss: 0.2133 - val_mean_absolute_error: 0.2966
# Epoch 142/150
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0212 - mean_absolute_error: 0.0991 - val_loss: 0.2137 - val_mean_absolute_error: 0.2957
# Epoch 143/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0210 - mean_absolute_error: 0.0969 - val_loss: 0.2123 - val_mean_absolute_error: 0.2949
# Epoch 144/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0212 - mean_absolute_error: 0.0981 - val_loss: 0.2132 - val_mean_absolute_error: 0.2968
# Epoch 145/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0208 - mean_absolute_error: 0.0967 - val_loss: 0.2153 - val_mean_absolute_error: 0.2975
# Epoch 146/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0207 - mean_absolute_error: 0.0964 - val_loss: 0.2143 - val_mean_absolute_error: 0.2978
# Epoch 147/150
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0202 - mean_absolute_error: 0.0951 - val_loss: 0.2161 - val_mean_absolute_error: 0.2978
# Epoch 148/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0203 - mean_absolute_error: 0.0956 - val_loss: 0.2176 - val_mean_absolute_error: 0.2988
# Epoch 149/150
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0200 - mean_absolute_error: 0.0943 - val_loss: 0.2163 - val_mean_absolute_error: 0.2976
# Epoch 150/150
# 3825/3825 [==============================] - 0s 17us/step - loss: 0.0207 - mean_absolute_error: 0.0973 - val_loss: 0.2141 - val_mean_absolute_error: 0.2984

# %%
preds = model.predict(X_test_sc)  # generate predictions on validation data
preds  # preview predictions
# Out:
# array([[4.5343118e+00],
#        [1.6986731e+00],
#        [1.2164838e+00],
#        ...,
#        [1.3426905e-03],
#        [2.4433663e+00],
#        [9.7396779e-01]], dtype=float32)

# %%
# Save training data loss and validation data loss as variables to plot:
train_loss = history.history['loss']     # 'loss' = mean squared error of training data
test_loss = history.history['val_loss']  # 'val_loss' = mean squared error of validation data

# Plot training and testing loss for the FFNN model:
plt.figure(figsize=(15, 10))
plt.plot(train_loss, label='Training loss', color='navy')
plt.plot(test_loss, label='Testing loss', color='skyblue')
plt.legend();

# Save figure as a PNG file:
plt.savefig('../../images/FFNN_fantasy_training_vs_testing_loss_function_2018.png')

# %%
# Assign predicted fantasy points to validation data as a new column:
X_test['Predicted_FP'] = preds
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Assign true fantasy points to validation data as a new column:
X_test['FantasyPoints'] = y_test
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
X_test.head()  # preview first 5 rows of validation data
# Now, predicted fantasy points per week can be visually compared to true values and all other data columns.
# Out:
#              Rank            Name Position  Week  PassingYards  \
# Date
# 2018-12-09  140.0  Donte Moncrief       WR    14           0.0
# 2018-12-02  214.0     Zach Pascal       WR    13           0.0
# 2018-09-23  245.0    Kenyan Drake       RB     3           0.0
# 2018-12-30   64.0       Rod Smith       RB    17           0.0
# 2018-09-09   80.0    Adam Thielen       WR     1           0.0
#
#             PassingTouchdowns  PassingInterceptions  RushingYards  \
# Date
# 2018-12-09                0.0                   0.0           0.0
# 2018-12-02                0.0                   0.0           2.0
# 2018-09-23                0.0                   0.0           3.0
# 2018-12-30                0.0                   0.0          35.0
# 2018-09-09                0.0                   0.0           0.0
#
#             RushingTouchdowns  Receptions  ...  Opponent_OAK  Opponent_PHI  \
# Date                                       ...
# 2018-12-09                0.0         5.0  ...           0.0           0.0
# 2018-12-02                0.0         1.0  ...           0.0           0.0
# 2018-09-23                0.0         2.0  ...           1.0           0.0
# 2018-12-30                1.0         2.0  ...           0.0           0.0
# 2018-09-09                0.0         6.0  ...           0.0           0.0
#
#             Opponent_PIT  Opponent_SEA  Opponent_SF  Opponent_TB  \
# Date
# 2018-12-09           0.0           0.0          0.0          0.0
# 2018-12-02           0.0           0.0          0.0          0.0
# 2018-09-23           0.0           0.0          0.0          0.0
# 2018-12-30           0.0           0.0          0.0          0.0
# 2018-09-09           0.0           0.0          1.0          0.0
#
#             Opponent_TEN  Opponent_WAS  Predicted_FP  FantasyPoints
# Date
# 2018-12-09           1.0           0.0      4.534312            4.7
# 2018-12-02           0.0           0.0      1.698673            1.8
# 2018-09-23           0.0           0.0      1.216484            1.0
# 2018-12-30           0.0           0.0     11.865455           10.9
# 2018-09-09           0.0           0.0      9.735585           10.2
#
# [5 rows x 80 columns]

# %%
# Calculate and display validation data MSE and RMSE:
test_mse = mean_squared_error(preds, y_test)
print('MSE = ', test_mse)
print('RMSE = ', np.sqrt(test_mse))
# Out:
# MSE =  0.21407178808299282
# RMSE =  0.46267892547963846

# %%
# Calculate and display training data MSE and RMSE:
train_preds = model.predict(X_train_sc)
train_mse = mean_squared_error(train_preds, y_train)
print('MSE = ', train_mse)
print('RMSE = ', np.sqrt(train_mse))
# Out:
# MSE =  0.019082231778812152
# RMSE =  0.13813845148550113
