# %%
# DataFrame manipulation libraries:
import pandas as pd
import numpy as np

# Visualization libraries:
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Evaluation and processing libraries:
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Keras libraries:
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, Dropout, GRU
from keras.optimizers import Adam
from keras.preprocessing.sequence import TimeseriesGenerator
# Out:
# Using TensorFlow backend.

# %%
# Load in CSV data of top player performance per week in the 2015, 2016, 2017, and 2018 NFL seasons:
df = pd.read_csv('../../clean_data/player_weekly_performance_2018.csv')
df.head()  # preview first 5 rows of dataframe
# Out:
#    Rank  PlayerID              Name Team Position  Week Opponent  \
# 0     1      8283  Ryan Fitzpatrick   TB       QB     1       NO
# 1     2     18878      Alvin Kamara   NO       RB     1       TB
# 2     3      7242        Drew Brees   NO       QB     1       TB
# 3     4     18082       Tyreek Hill   KC       WR     1      LAC
# 4     5     18983      James Conner  PIT       RB     1      CLE
#
#    PassingYards  PassingTouchdowns  PassingInterceptions  RushingYards  \
# 0           417                  4                     0            36
# 1             0                  0                     0            29
# 2           439                  3                     0             0
# 3             0                  0                     0             4
# 4             0                  0                     0           135
#
#    RushingTouchdowns  Receptions  ReceivingYards  ReceivingTouchdowns  \
# 0                  1           0               0                    0
# 1                  2           9             112                    1
# 2                  0           0               0                    0
# 3                  0           7             169                    2
# 4                  2           5              57                    0
#
#    FumblesLost  FantasyPoints        Date  Year
# 0            0          42.28  2018-09-09  2018
# 1            0          34.10  2018-09-09  2018
# 2            0          31.56  2018-09-09  2018
# 3            0          29.30  2018-09-09  2018
# 4            1          29.20  2018-09-09  2018

# %%
df['Date'] = pd.to_datetime(df['Date'], format = '%Y-%m-%d') # Convert 'Date' feature into a Pandas datetime object
df.dtypes  # examine data types of features
# Out:
# Rank                             int64
# PlayerID                         int64
# Name                            object
# Team                            object
# Position                        object
# Week                             int64
# Opponent                        object
# PassingYards                     int64
# PassingTouchdowns                int64
# PassingInterceptions             int64
# RushingYards                     int64
# RushingTouchdowns                int64
# Receptions                       int64
# ReceivingYards                   int64
# ReceivingTouchdowns              int64
# FumblesLost                      int64
# FantasyPoints                  float64
# Date                    datetime64[ns]
# Year                             int64
# dtype: object

# %%
df.set_index('Date', inplace=True)  # set Date as the index
df.sort_index(inplace=True)         # sort the dataframe by the Date index
df.head()                           # examine first 5 rows to verify changes
# Out:
#             Rank  PlayerID              Name Team Position  Week Opponent  \
# Date
# 2018-09-09     1      8283  Ryan Fitzpatrick   TB       QB     1       NO
# 2018-09-09     2     18878      Alvin Kamara   NO       RB     1       TB
# 2018-09-09     3      7242        Drew Brees   NO       QB     1       TB
# 2018-09-09     4     18082       Tyreek Hill   KC       WR     1      LAC
# 2018-09-09     5     18983      James Conner  PIT       RB     1      CLE
#
#             PassingYards  PassingTouchdowns  PassingInterceptions  \
# Date
# 2018-09-09           417                  4                     0
# 2018-09-09             0                  0                     0
# 2018-09-09           439                  3                     0
# 2018-09-09             0                  0                     0
# 2018-09-09             0                  0                     0
#
#             RushingYards  RushingTouchdowns  Receptions  ReceivingYards  \
# Date
# 2018-09-09            36                  1           0               0
# 2018-09-09            29                  2           9             112
# 2018-09-09             0                  0           0               0
# 2018-09-09             4                  0           7             169
# 2018-09-09           135                  2           5              57
#
#             ReceivingTouchdowns  FumblesLost  FantasyPoints  Year
# Date
# 2018-09-09                    0            0          42.28  2018
# 2018-09-09                    1            0          34.10  2018
# 2018-09-09                    0            0          31.56  2018
# 2018-09-09                    2            0          29.30  2018
# 2018-09-09                    0            1          29.20  2018

# %%
df.shape  # preview dataframe dimensions; 20,400 rows and 17 columns as features
# Out:
# (5100, 18)

# %%
# Convert player's team, opponent, and position into one-hot encoded variables to use for FFNN:
df_with_dummies = pd.get_dummies(df, columns=['Team', 'Opponent'], drop_first=False)

# Select feature variables to convert into floats; prevents errors when scaling data with StandardScaler:
features = [col for col in df_with_dummies.columns if col not in ['Name', 'Position', 'Week', 'Year', 'PlayerID']]
df_with_dummies[features] = df_with_dummies[features].astype(float)

# Assign X as features to be used for predicting weekly fantasy points per player:
X = df_with_dummies[[col for col in df_with_dummies.columns if col not in ['FantasyPoints', 'PlayerID']]]
# Assign target vector y as weekly fantasy points per player:
y = df_with_dummies['FantasyPoints']

# %%
X.dtypes  # verify that data types have been properly cast
# Out:
# Rank                    float64
# Name                     object
# Position                 object
# Week                      int64
# PassingYards            float64
# PassingTouchdowns       float64
# PassingInterceptions    float64
# RushingYards            float64
# RushingTouchdowns       float64
# Receptions              float64
# ReceivingYards          float64
# ReceivingTouchdowns     float64
# FumblesLost             float64
# Year                      int64
# Team_ARI                float64
# Team_ATL                float64
# Team_BAL                float64
# Team_BUF                float64
# Team_CAR                float64
# Team_CHI                float64
# Team_CIN                float64
# Team_CLE                float64
# Team_DAL                float64
# Team_DEN                float64
# Team_DET                float64
# Team_GB                 float64
# Team_HOU                float64
# Team_IND                float64
# Team_JAX                float64
# Team_KC                 float64
#                          ...
# Opponent_BAL            float64
# Opponent_BUF            float64
# Opponent_CAR            float64
# Opponent_CHI            float64
# Opponent_CIN            float64
# Opponent_CLE            float64
# Opponent_DAL            float64
# Opponent_DEN            float64
# Opponent_DET            float64
# Opponent_GB             float64
# Opponent_HOU            float64
# Opponent_IND            float64
# Opponent_JAX            float64
# Opponent_KC             float64
# Opponent_LAC            float64
# Opponent_LAR            float64
# Opponent_MIA            float64
# Opponent_MIN            float64
# Opponent_NE             float64
# Opponent_NO             float64
# Opponent_NYG            float64
# Opponent_NYJ            float64
# Opponent_OAK            float64
# Opponent_PHI            float64
# Opponent_PIT            float64
# Opponent_SEA            float64
# Opponent_SF             float64
# Opponent_TB             float64
# Opponent_TEN            float64
# Opponent_WAS            float64
# Length: 78, dtype: object

# %%
# Split X and y data into a training set and validation set:
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Scale all columns to use as predictive features using StandardScaler:
ss = StandardScaler()
X_train_sc = ss.fit_transform(X_train.drop(columns = ['Name', 'Position', 'Week', 'Year']))
X_test_sc = ss.transform(X_test.drop(columns = ['Name', 'Position', 'Week', 'Year']))

# %%
X_test_sc[0:5]  # preview first 5 scaled X values in the validation data
# Out:
# array([[-0.07630398, -0.31715918, -0.26621033, -0.20776738, -0.45487011,
#         -0.26056741,  1.15984546,  0.66307007, -0.39695878, -0.19570613,
#         -0.17684817, -0.18074121, -0.19346525, -0.19053746, -0.17367869,
#         -0.17447582, -0.16718097, -0.18151105, -0.18380366, -0.18227804,
#         -0.18831599, -0.17996851, -0.17684817, -0.18151105,  5.89471488,
#         -0.18074121, -0.17684817, -0.16215612, -0.17996851, -0.17841432,
#         -0.19273688, -0.18304223, -0.17684817, -0.17606051, -0.19200614,
#         -0.18151105, -0.17841432, -0.17919289, -0.17447582, -0.17606051,
#         -0.18074121, -0.17367869, -0.18074121, -0.19273688, -0.17367869,
#         -0.17919289, -0.17841432, -0.18456235, -0.18304223, -0.17447582,
#         -0.17763276, -0.17606051, -0.18227804, -0.17919289, -0.19200614,
#         -0.17526974, -0.17526974, -0.18831599, -0.17606051, -0.17126767,
#         -0.17996851, -0.17207467, -0.18074121, -0.16964349, -0.18682237,
#         -0.18380366, -0.18531834, -0.17287832, -0.17996851, -0.17526974,
#         -0.17919289, -0.17526974,  5.3526781 , -0.17684817],
#        [ 0.81502704, -0.31715918, -0.26621033, -0.20776738, -0.37688714,
#         -0.26056741, -0.5215678 , -0.30377122, -0.39695878, -0.19570613,
#         -0.17684817, -0.18074121, -0.19346525, -0.19053746, -0.17367869,
#         -0.17447582, -0.16718097, -0.18151105, -0.18380366, -0.18227804,
#         -0.18831599, -0.17996851, -0.17684817,  5.50930658, -0.16964349,
#         -0.18074121, -0.17684817, -0.16215612, -0.17996851, -0.17841432,
#         -0.19273688, -0.18304223, -0.17684817, -0.17606051, -0.19200614,
#         -0.18151105, -0.17841432, -0.17919289, -0.17447582, -0.17606051,
#         -0.18074121, -0.17367869, -0.18074121, -0.19273688, -0.17367869,
#         -0.17919289, -0.17841432, -0.18456235, -0.18304223, -0.17447582,
#         -0.17763276, -0.17606051, -0.18227804, -0.17919289, -0.19200614,
#         -0.17526974,  5.70549135, -0.18831599, -0.17606051, -0.17126767,
#         -0.17996851, -0.17207467, -0.18074121, -0.16964349, -0.18682237,
#         -0.18380366, -0.18531834, -0.17287832, -0.17996851, -0.17526974,
#         -0.17919289, -0.17526974, -0.18682237, -0.17684817],
#        [ 1.18842246, -0.31715918, -0.26621033, -0.20776738, -0.33789565,
#         -0.26056741, -0.10121448, -0.58446707, -0.39695878, -0.19570613,
#         -0.17684817, -0.18074121, -0.19346525, -0.19053746, -0.17367869,
#         -0.17447582, -0.16718097, -0.18151105, -0.18380366, -0.18227804,
#         -0.18831599, -0.17996851, -0.17684817, -0.18151105, -0.16964349,
#         -0.18074121, -0.17684817, -0.16215612,  5.55652769, -0.17841432,
#         -0.19273688, -0.18304223, -0.17684817, -0.17606051, -0.19200614,
#         -0.18151105, -0.17841432, -0.17919289, -0.17447582, -0.17606051,
#         -0.18074121, -0.17367869, -0.18074121, -0.19273688, -0.17367869,
#         -0.17919289, -0.17841432, -0.18456235, -0.18304223, -0.17447582,
#         -0.17763276, -0.17606051, -0.18227804, -0.17919289, -0.19200614,
#         -0.17526974, -0.17526974, -0.18831599, -0.17606051, -0.17126767,
#         -0.17996851, -0.17207467, -0.18074121, -0.16964349, -0.18682237,
#         -0.18380366,  5.39611992, -0.17287832, -0.17996851, -0.17526974,
#         -0.17919289, -0.17526974, -0.18682237, -0.17684817],
#        [-0.99172503, -0.31715918, -0.26621033, -0.20776738,  0.90983197,
#          2.69691134, -0.10121448, -0.36614807, -0.39695878, -0.19570613,
#         -0.17684817, -0.18074121, -0.19346525, -0.19053746, -0.17367869,
#         -0.17447582, -0.16718097, -0.18151105,  5.4405882 , -0.18227804,
#         -0.18831599, -0.17996851, -0.17684817, -0.18151105, -0.16964349,
#         -0.18074121, -0.17684817, -0.16215612, -0.17996851, -0.17841432,
#         -0.19273688, -0.18304223, -0.17684817, -0.17606051, -0.19200614,
#         -0.18151105, -0.17841432, -0.17919289, -0.17447582, -0.17606051,
#         -0.18074121, -0.17367869, -0.18074121, -0.19273688, -0.17367869,
#         -0.17919289, -0.17841432, -0.18456235, -0.18304223, -0.17447582,
#         -0.17763276, -0.17606051, -0.18227804, -0.17919289, -0.19200614,
#         -0.17526974, -0.17526974, -0.18831599, -0.17606051, -0.17126767,
#         -0.17996851, -0.17207467, -0.18074121, -0.16964349,  5.3526781 ,
#         -0.18380366, -0.18531834, -0.17287832, -0.17996851, -0.17526974,
#         -0.17919289, -0.17526974, -0.18682237, -0.17684817],
#        [-0.79900481, -0.31715918, -0.26621033, -0.20776738, -0.45487011,
#         -0.26056741,  1.58019878,  2.37843364, -0.39695878, -0.19570613,
#         -0.17684817, -0.18074121, -0.19346525, -0.19053746, -0.17367869,
#         -0.17447582, -0.16718097, -0.18151105, -0.18380366, -0.18227804,
#         -0.18831599, -0.17996851, -0.17684817, -0.18151105, -0.16964349,
#         -0.18074121, -0.17684817, -0.16215612, -0.17996851,  5.60493124,
#         -0.19273688, -0.18304223, -0.17684817, -0.17606051, -0.19200614,
#         -0.18151105, -0.17841432, -0.17919289, -0.17447582, -0.17606051,
#         -0.18074121, -0.17367869, -0.18074121, -0.19273688, -0.17367869,
#         -0.17919289, -0.17841432, -0.18456235, -0.18304223, -0.17447582,
#         -0.17763276, -0.17606051, -0.18227804, -0.17919289, -0.19200614,
#         -0.17526974, -0.17526974, -0.18831599, -0.17606051, -0.17126767,
#         -0.17996851, -0.17207467, -0.18074121, -0.16964349, -0.18682237,
#         -0.18380366, -0.18531834, -0.17287832, -0.17996851, -0.17526974,
#          5.58057857, -0.17526974, -0.18682237, -0.17684817]])

# %%
X_test_sc.shape  # check shape of scaled X validation data
# Out:
# (1275, 74)

# %%
# Instantiate and build feed-forward neural network to predict player performance per week:
model = Sequential()                                        # instantiate model
model.add(Dense(74, activation='relu', input_shape=(74,)))  # input layer with 74 neurons
model.add(Dense(74, activation='relu'))                     # first hidden layer with 74 neurons
model.add(Dense(37, activation='relu'))                     # second hidden layer with 37 neurons
model.add(Dense(1))                                         # output layer with 1 neuron; represents predicted points
# Out:
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=15, verbose=1, mode='auto')

# %%
# Compile the FFNN model:
model.compile(loss='mse', optimizer='adam', metrics=['mae'])
# loss function = mean squared error
# optimization function = adam
# evaluation metric = mean absolute error

# %%
# Train the FFNN model using training, error is measured using validation data:
history = model.fit(X_train_sc, y_train, validation_data=(X_test_sc, y_test), epochs=120, 
                    batch_size=256) #, callbacks = [early_stop])
# Out:
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 3825 samples, validate on 1275 samples
# Epoch 1/120
# 3825/3825 [==============================] - 0s 87us/step - loss: 80.8871 - mean_absolute_error: 5.8969 - val_loss: 53.5896 - val_mean_absolute_error: 4.9083
# Epoch 2/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 47.2769 - mean_absolute_error: 5.1307 - val_loss: 36.7650 - val_mean_absolute_error: 5.1385
# Epoch 3/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 31.9461 - mean_absolute_error: 4.6865 - val_loss: 23.6331 - val_mean_absolute_error: 4.0079
# Epoch 4/120
# 3825/3825 [==============================] - 0s 16us/step - loss: 19.4837 - mean_absolute_error: 3.5515 - val_loss: 14.2009 - val_mean_absolute_error: 3.1137
# Epoch 5/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 10.3882 - mean_absolute_error: 2.6182 - val_loss: 6.9684 - val_mean_absolute_error: 2.1055
# Epoch 6/120
# 3825/3825 [==============================] - 0s 16us/step - loss: 4.6638 - mean_absolute_error: 1.6646 - val_loss: 2.9641 - val_mean_absolute_error: 1.2953
# Epoch 7/120
# 3825/3825 [==============================] - 0s 18us/step - loss: 2.1420 - mean_absolute_error: 1.0809 - val_loss: 1.6598 - val_mean_absolute_error: 0.9620
# Epoch 8/120
# 3825/3825 [==============================] - 0s 19us/step - loss: 1.3635 - mean_absolute_error: 0.8654 - val_loss: 1.2521 - val_mean_absolute_error: 0.8488
# Epoch 9/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 1.0375 - mean_absolute_error: 0.7684 - val_loss: 1.0173 - val_mean_absolute_error: 0.7757
# Epoch 10/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.8460 - mean_absolute_error: 0.6997 - val_loss: 0.8788 - val_mean_absolute_error: 0.7239
# Epoch 11/120
# 3825/3825 [==============================] - 0s 18us/step - loss: 0.7180 - mean_absolute_error: 0.6446 - val_loss: 0.7813 - val_mean_absolute_error: 0.6817
# Epoch 12/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.6143 - mean_absolute_error: 0.5949 - val_loss: 0.7028 - val_mean_absolute_error: 0.6431
# Epoch 13/120
# 3825/3825 [==============================] - 0s 17us/step - loss: 0.5287 - mean_absolute_error: 0.5505 - val_loss: 0.6681 - val_mean_absolute_error: 0.6224
# Epoch 14/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.4709 - mean_absolute_error: 0.5206 - val_loss: 0.6081 - val_mean_absolute_error: 0.5925
# Epoch 15/120
# 3825/3825 [==============================] - 0s 20us/step - loss: 0.4169 - mean_absolute_error: 0.4929 - val_loss: 0.5472 - val_mean_absolute_error: 0.5635
# Epoch 16/120
# 3825/3825 [==============================] - 0s 16us/step - loss: 0.3732 - mean_absolute_error: 0.4623 - val_loss: 0.5110 - val_mean_absolute_error: 0.5413
# Epoch 17/120
# 3825/3825 [==============================] - 0s 17us/step - loss: 0.3367 - mean_absolute_error: 0.4395 - val_loss: 0.4835 - val_mean_absolute_error: 0.5244
# Epoch 18/120
# 3825/3825 [==============================] - 0s 19us/step - loss: 0.3073 - mean_absolute_error: 0.4209 - val_loss: 0.4582 - val_mean_absolute_error: 0.5080
# Epoch 19/120
# 3825/3825 [==============================] - 0s 17us/step - loss: 0.2875 - mean_absolute_error: 0.4059 - val_loss: 0.4347 - val_mean_absolute_error: 0.4913
# Epoch 20/120
# 3825/3825 [==============================] - 0s 16us/step - loss: 0.2607 - mean_absolute_error: 0.3860 - val_loss: 0.4231 - val_mean_absolute_error: 0.4836
# Epoch 21/120
# 3825/3825 [==============================] - 0s 18us/step - loss: 0.2447 - mean_absolute_error: 0.3735 - val_loss: 0.4048 - val_mean_absolute_error: 0.4716
# Epoch 22/120
# 3825/3825 [==============================] - 0s 18us/step - loss: 0.2290 - mean_absolute_error: 0.3597 - val_loss: 0.3964 - val_mean_absolute_error: 0.4641
# Epoch 23/120
# 3825/3825 [==============================] - 0s 17us/step - loss: 0.2148 - mean_absolute_error: 0.3497 - val_loss: 0.3735 - val_mean_absolute_error: 0.4497
# Epoch 24/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.2028 - mean_absolute_error: 0.3374 - val_loss: 0.3584 - val_mean_absolute_error: 0.4373
# Epoch 25/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.1962 - mean_absolute_error: 0.3306 - val_loss: 0.3481 - val_mean_absolute_error: 0.4307
# Epoch 26/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.1825 - mean_absolute_error: 0.3186 - val_loss: 0.3404 - val_mean_absolute_error: 0.4239
# Epoch 27/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.1727 - mean_absolute_error: 0.3099 - val_loss: 0.3353 - val_mean_absolute_error: 0.4192
# Epoch 28/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.1663 - mean_absolute_error: 0.3036 - val_loss: 0.3264 - val_mean_absolute_error: 0.4133
# Epoch 29/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.1587 - mean_absolute_error: 0.2964 - val_loss: 0.3139 - val_mean_absolute_error: 0.4029
# Epoch 30/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.1519 - mean_absolute_error: 0.2888 - val_loss: 0.3048 - val_mean_absolute_error: 0.3962
# Epoch 31/120
# 3825/3825 [==============================] - 0s 17us/step - loss: 0.1449 - mean_absolute_error: 0.2813 - val_loss: 0.2987 - val_mean_absolute_error: 0.3903
# Epoch 32/120
# 3825/3825 [==============================] - 0s 18us/step - loss: 0.1389 - mean_absolute_error: 0.2756 - val_loss: 0.2948 - val_mean_absolute_error: 0.3873
# Epoch 33/120
# 3825/3825 [==============================] - 0s 17us/step - loss: 0.1333 - mean_absolute_error: 0.2697 - val_loss: 0.2896 - val_mean_absolute_error: 0.3830
# Epoch 34/120
# 3825/3825 [==============================] - 0s 16us/step - loss: 0.1290 - mean_absolute_error: 0.2641 - val_loss: 0.2825 - val_mean_absolute_error: 0.3755
# Epoch 35/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.1256 - mean_absolute_error: 0.2587 - val_loss: 0.2784 - val_mean_absolute_error: 0.3731
# Epoch 36/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.1198 - mean_absolute_error: 0.2540 - val_loss: 0.2788 - val_mean_absolute_error: 0.3744
# Epoch 37/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.1159 - mean_absolute_error: 0.2487 - val_loss: 0.2834 - val_mean_absolute_error: 0.3759
# Epoch 38/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.1139 - mean_absolute_error: 0.2473 - val_loss: 0.2647 - val_mean_absolute_error: 0.3615
# Epoch 39/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.1082 - mean_absolute_error: 0.2405 - val_loss: 0.2721 - val_mean_absolute_error: 0.3672
# Epoch 40/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.1048 - mean_absolute_error: 0.2363 - val_loss: 0.2669 - val_mean_absolute_error: 0.3631
# Epoch 41/120
# 3825/3825 [==============================] - ETA: 0s - loss: 0.1079 - mean_absolute_error: 0.229 - 0s 12us/step - loss: 0.1020 - mean_absolute_error: 0.2339 - val_loss: 0.2564 - val_mean_absolute_error: 0.3538
# Epoch 42/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0994 - mean_absolute_error: 0.2298 - val_loss: 0.2579 - val_mean_absolute_error: 0.3529
# Epoch 43/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0966 - mean_absolute_error: 0.2262 - val_loss: 0.2484 - val_mean_absolute_error: 0.3475
# Epoch 44/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0961 - mean_absolute_error: 0.2248 - val_loss: 0.2536 - val_mean_absolute_error: 0.3506
# Epoch 45/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0925 - mean_absolute_error: 0.2205 - val_loss: 0.2483 - val_mean_absolute_error: 0.3463
# Epoch 46/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0892 - mean_absolute_error: 0.2167 - val_loss: 0.2456 - val_mean_absolute_error: 0.3420
# Epoch 47/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0878 - mean_absolute_error: 0.2149 - val_loss: 0.2441 - val_mean_absolute_error: 0.3415
# Epoch 48/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0857 - mean_absolute_error: 0.2120 - val_loss: 0.2398 - val_mean_absolute_error: 0.3368
# Epoch 49/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0824 - mean_absolute_error: 0.2084 - val_loss: 0.2456 - val_mean_absolute_error: 0.3427
# Epoch 50/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.0845 - mean_absolute_error: 0.2116 - val_loss: 0.2341 - val_mean_absolute_error: 0.3314
# Epoch 51/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0813 - mean_absolute_error: 0.2068 - val_loss: 0.2355 - val_mean_absolute_error: 0.3335
# Epoch 52/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0768 - mean_absolute_error: 0.2012 - val_loss: 0.2356 - val_mean_absolute_error: 0.3336
# Epoch 53/120
# 3825/3825 [==============================] - 0s 11us/step - loss: 0.0753 - mean_absolute_error: 0.1990 - val_loss: 0.2318 - val_mean_absolute_error: 0.3297
# Epoch 54/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0732 - mean_absolute_error: 0.1958 - val_loss: 0.2266 - val_mean_absolute_error: 0.3252
# Epoch 55/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0724 - mean_absolute_error: 0.1955 - val_loss: 0.2308 - val_mean_absolute_error: 0.3284
# Epoch 56/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0714 - mean_absolute_error: 0.1920 - val_loss: 0.2302 - val_mean_absolute_error: 0.3265
# Epoch 57/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0704 - mean_absolute_error: 0.1916 - val_loss: 0.2277 - val_mean_absolute_error: 0.3255
# Epoch 58/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0686 - mean_absolute_error: 0.1895 - val_loss: 0.2233 - val_mean_absolute_error: 0.3208
# Epoch 59/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0670 - mean_absolute_error: 0.1863 - val_loss: 0.2355 - val_mean_absolute_error: 0.3309
# Epoch 60/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0664 - mean_absolute_error: 0.1858 - val_loss: 0.2221 - val_mean_absolute_error: 0.3194
# Epoch 61/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0641 - mean_absolute_error: 0.1820 - val_loss: 0.2205 - val_mean_absolute_error: 0.3189
# Epoch 62/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0628 - mean_absolute_error: 0.1802 - val_loss: 0.2211 - val_mean_absolute_error: 0.3192
# Epoch 63/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0614 - mean_absolute_error: 0.1776 - val_loss: 0.2231 - val_mean_absolute_error: 0.3203
# Epoch 64/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0606 - mean_absolute_error: 0.1774 - val_loss: 0.2228 - val_mean_absolute_error: 0.3183
# Epoch 65/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0598 - mean_absolute_error: 0.1747 - val_loss: 0.2164 - val_mean_absolute_error: 0.3149
# Epoch 66/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0584 - mean_absolute_error: 0.1730 - val_loss: 0.2169 - val_mean_absolute_error: 0.3143
# Epoch 67/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0569 - mean_absolute_error: 0.1706 - val_loss: 0.2219 - val_mean_absolute_error: 0.3172
# Epoch 68/120
# 3825/3825 [==============================] - 0s 19us/step - loss: 0.0567 - mean_absolute_error: 0.1695 - val_loss: 0.2178 - val_mean_absolute_error: 0.3148
# Epoch 69/120
# 3825/3825 [==============================] - 0s 21us/step - loss: 0.0549 - mean_absolute_error: 0.1671 - val_loss: 0.2155 - val_mean_absolute_error: 0.3134
# Epoch 70/120
# 3825/3825 [==============================] - 0s 21us/step - loss: 0.0546 - mean_absolute_error: 0.1673 - val_loss: 0.2178 - val_mean_absolute_error: 0.3137
# Epoch 71/120
# 3825/3825 [==============================] - 0s 22us/step - loss: 0.0535 - mean_absolute_error: 0.1651 - val_loss: 0.2170 - val_mean_absolute_error: 0.3137
# Epoch 72/120
# 3825/3825 [==============================] - 0s 26us/step - loss: 0.0528 - mean_absolute_error: 0.1639 - val_loss: 0.2108 - val_mean_absolute_error: 0.3091
# Epoch 73/120
# 3825/3825 [==============================] - 0s 22us/step - loss: 0.0523 - mean_absolute_error: 0.1626 - val_loss: 0.2173 - val_mean_absolute_error: 0.3126
# Epoch 74/120
# 3825/3825 [==============================] - 0s 22us/step - loss: 0.0500 - mean_absolute_error: 0.1586 - val_loss: 0.2114 - val_mean_absolute_error: 0.3085
# Epoch 75/120
# 3825/3825 [==============================] - 0s 20us/step - loss: 0.0498 - mean_absolute_error: 0.1591 - val_loss: 0.2083 - val_mean_absolute_error: 0.3063
# Epoch 76/120
# 3825/3825 [==============================] - 0s 21us/step - loss: 0.0503 - mean_absolute_error: 0.1598 - val_loss: 0.2191 - val_mean_absolute_error: 0.3132
# Epoch 77/120
# 3825/3825 [==============================] - 0s 22us/step - loss: 0.0490 - mean_absolute_error: 0.1574 - val_loss: 0.2140 - val_mean_absolute_error: 0.3093
# Epoch 78/120
# 3825/3825 [==============================] - 0s 22us/step - loss: 0.0471 - mean_absolute_error: 0.1545 - val_loss: 0.2080 - val_mean_absolute_error: 0.3059
# Epoch 79/120
# 3825/3825 [==============================] - 0s 21us/step - loss: 0.0469 - mean_absolute_error: 0.1535 - val_loss: 0.2078 - val_mean_absolute_error: 0.3042
# Epoch 80/120
# 3825/3825 [==============================] - 0s 20us/step - loss: 0.0463 - mean_absolute_error: 0.1519 - val_loss: 0.2096 - val_mean_absolute_error: 0.3059
# Epoch 81/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0449 - mean_absolute_error: 0.1501 - val_loss: 0.2069 - val_mean_absolute_error: 0.3029
# Epoch 82/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0446 - mean_absolute_error: 0.1491 - val_loss: 0.2067 - val_mean_absolute_error: 0.3034
# Epoch 83/120
# 3825/3825 [==============================] - 0s 18us/step - loss: 0.0440 - mean_absolute_error: 0.1487 - val_loss: 0.2068 - val_mean_absolute_error: 0.3020
# Epoch 84/120
# 3825/3825 [==============================] - 0s 18us/step - loss: 0.0436 - mean_absolute_error: 0.1481 - val_loss: 0.2063 - val_mean_absolute_error: 0.3029
# Epoch 85/120
# 3825/3825 [==============================] - 0s 18us/step - loss: 0.0428 - mean_absolute_error: 0.1463 - val_loss: 0.2127 - val_mean_absolute_error: 0.3072
# Epoch 86/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.0428 - mean_absolute_error: 0.1460 - val_loss: 0.2069 - val_mean_absolute_error: 0.3024
# Epoch 87/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.0411 - mean_absolute_error: 0.1434 - val_loss: 0.2046 - val_mean_absolute_error: 0.2997
# Epoch 88/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.0406 - mean_absolute_error: 0.1413 - val_loss: 0.2085 - val_mean_absolute_error: 0.3023
# Epoch 89/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0404 - mean_absolute_error: 0.1420 - val_loss: 0.2024 - val_mean_absolute_error: 0.2981
# Epoch 90/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0392 - mean_absolute_error: 0.1393 - val_loss: 0.2138 - val_mean_absolute_error: 0.3068
# Epoch 91/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0398 - mean_absolute_error: 0.1408 - val_loss: 0.2030 - val_mean_absolute_error: 0.2983
# Epoch 92/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0386 - mean_absolute_error: 0.1380 - val_loss: 0.2048 - val_mean_absolute_error: 0.3006
# Epoch 93/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0389 - mean_absolute_error: 0.1391 - val_loss: 0.2129 - val_mean_absolute_error: 0.3044
# Epoch 94/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0392 - mean_absolute_error: 0.1391 - val_loss: 0.2067 - val_mean_absolute_error: 0.3019
# Epoch 95/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0393 - mean_absolute_error: 0.1396 - val_loss: 0.2046 - val_mean_absolute_error: 0.2977
# Epoch 96/120
# 3825/3825 [==============================] - 0s 21us/step - loss: 0.0367 - mean_absolute_error: 0.1347 - val_loss: 0.2025 - val_mean_absolute_error: 0.2980
# Epoch 97/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.0364 - mean_absolute_error: 0.1337 - val_loss: 0.2013 - val_mean_absolute_error: 0.2966
# Epoch 98/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0352 - mean_absolute_error: 0.1310 - val_loss: 0.2044 - val_mean_absolute_error: 0.2981
# Epoch 99/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0348 - mean_absolute_error: 0.1304 - val_loss: 0.2047 - val_mean_absolute_error: 0.2984
# Epoch 100/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0355 - mean_absolute_error: 0.1323 - val_loss: 0.2011 - val_mean_absolute_error: 0.2958
# Epoch 101/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0349 - mean_absolute_error: 0.1302 - val_loss: 0.2032 - val_mean_absolute_error: 0.2970
# Epoch 102/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0342 - mean_absolute_error: 0.1284 - val_loss: 0.2036 - val_mean_absolute_error: 0.2960
# Epoch 103/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0341 - mean_absolute_error: 0.1296 - val_loss: 0.2011 - val_mean_absolute_error: 0.2948
# Epoch 104/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0332 - mean_absolute_error: 0.1274 - val_loss: 0.2026 - val_mean_absolute_error: 0.2950
# Epoch 105/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0336 - mean_absolute_error: 0.1284 - val_loss: 0.2061 - val_mean_absolute_error: 0.2989
# Epoch 106/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0325 - mean_absolute_error: 0.1255 - val_loss: 0.2015 - val_mean_absolute_error: 0.2945
# Epoch 107/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0320 - mean_absolute_error: 0.1241 - val_loss: 0.1993 - val_mean_absolute_error: 0.2931
# Epoch 108/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0324 - mean_absolute_error: 0.1249 - val_loss: 0.2032 - val_mean_absolute_error: 0.2954
# Epoch 109/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0315 - mean_absolute_error: 0.1230 - val_loss: 0.2014 - val_mean_absolute_error: 0.2934
# Epoch 110/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0308 - mean_absolute_error: 0.1219 - val_loss: 0.2026 - val_mean_absolute_error: 0.2947
# Epoch 111/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0304 - mean_absolute_error: 0.1209 - val_loss: 0.2046 - val_mean_absolute_error: 0.2940
# Epoch 112/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0307 - mean_absolute_error: 0.1217 - val_loss: 0.2033 - val_mean_absolute_error: 0.2953
# Epoch 113/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0302 - mean_absolute_error: 0.1200 - val_loss: 0.1998 - val_mean_absolute_error: 0.2927
# Epoch 114/120
# 3825/3825 [==============================] - 0s 15us/step - loss: 0.0300 - mean_absolute_error: 0.1191 - val_loss: 0.2003 - val_mean_absolute_error: 0.2925
# Epoch 115/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0292 - mean_absolute_error: 0.1184 - val_loss: 0.1984 - val_mean_absolute_error: 0.2907
# Epoch 116/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0293 - mean_absolute_error: 0.1183 - val_loss: 0.2040 - val_mean_absolute_error: 0.2945
# Epoch 117/120
# 3825/3825 [==============================] - 0s 13us/step - loss: 0.0285 - mean_absolute_error: 0.1166 - val_loss: 0.2032 - val_mean_absolute_error: 0.2926
# Epoch 118/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0295 - mean_absolute_error: 0.1192 - val_loss: 0.2116 - val_mean_absolute_error: 0.3014
# Epoch 119/120
# 3825/3825 [==============================] - 0s 14us/step - loss: 0.0306 - mean_absolute_error: 0.1217 - val_loss: 0.2113 - val_mean_absolute_error: 0.2990
# Epoch 120/120
# 3825/3825 [==============================] - 0s 12us/step - loss: 0.0288 - mean_absolute_error: 0.1171 - val_loss: 0.2041 - val_mean_absolute_error: 0.2946

# %%
preds = model.predict(X_test_sc)  # generate predictions on validation data
preds  # preview predictions
# Out:
# array([[4.7708526 ],
#        [1.6270382 ],
#        [0.99604136],
#        ...,
#        [0.08966096],
#        [2.1732762 ],
#        [0.73367757]], dtype=float32)

# %%
# Save training data loss and validation data loss as variables to plot:
train_loss = history.history['loss']     # 'loss' = mean squared error of training data
test_loss = history.history['val_loss']  # 'val_loss' = mean squared error of validation data

# Plot training and testing loss for the FFNN model:
plt.figure(figsize=(15, 10))
plt.plot(train_loss, label='Training loss', color='navy')
plt.plot(test_loss, label='Testing loss', color='skyblue')
plt.title('Feed-Forward Neural Network Training Loss vs. Testing Loss', size=20)
plt.xlabel('Number of Epochs', size=18)
plt.ylabel('Mean Squared Error', size=18)
plt.xticks(size=16)
plt.yticks(size=16)
plt.legend(fontsize=18);

# Save figure as a PNG file:
plt.savefig('../../images/FFNN_fantasy_training_vs_testing_loss_function_2018.png')

# %%
# Assign predicted fantasy points to validation data as a new column:
X_test['Predicted_FP'] = preds
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Assign true fantasy points to validation data as a new column:
X_test['FantasyPoints'] = y_test
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
X_test.head()  # preview first 5 rows of validation data
# Now, predicted fantasy points per week can be visually compared to true values and all other data columns.
# Out:
#              Rank            Name Position  Week  PassingYards  \
# Date
# 2018-12-09  140.0  Donte Moncrief       WR    14           0.0
# 2018-12-02  214.0     Zach Pascal       WR    13           0.0
# 2018-09-23  245.0    Kenyan Drake       RB     3           0.0
# 2018-12-30   64.0       Rod Smith       RB    17           0.0
# 2018-09-09   80.0    Adam Thielen       WR     1           0.0
#
#             PassingTouchdowns  PassingInterceptions  RushingYards  \
# Date
# 2018-12-09                0.0                   0.0           0.0
# 2018-12-02                0.0                   0.0           2.0
# 2018-09-23                0.0                   0.0           3.0
# 2018-12-30                0.0                   0.0          35.0
# 2018-09-09                0.0                   0.0           0.0
#
#             RushingTouchdowns  Receptions  ...  Opponent_OAK  Opponent_PHI  \
# Date                                       ...
# 2018-12-09                0.0         5.0  ...           0.0           0.0
# 2018-12-02                0.0         1.0  ...           0.0           0.0
# 2018-09-23                0.0         2.0  ...           1.0           0.0
# 2018-12-30                1.0         2.0  ...           0.0           0.0
# 2018-09-09                0.0         6.0  ...           0.0           0.0
#
#             Opponent_PIT  Opponent_SEA  Opponent_SF  Opponent_TB  \
# Date
# 2018-12-09           0.0           0.0          0.0          0.0
# 2018-12-02           0.0           0.0          0.0          0.0
# 2018-09-23           0.0           0.0          0.0          0.0
# 2018-12-30           0.0           0.0          0.0          0.0
# 2018-09-09           0.0           0.0          1.0          0.0
#
#             Opponent_TEN  Opponent_WAS  Predicted_FP  FantasyPoints
# Date
# 2018-12-09           1.0           0.0      4.770853            4.7
# 2018-12-02           0.0           0.0      1.627038            1.8
# 2018-09-23           0.0           0.0      0.996041            1.0
# 2018-12-30           0.0           0.0     11.413325           10.9
# 2018-09-09           0.0           0.0     10.074462           10.2
#
# [5 rows x 80 columns]

# %%
# Calculate and display validation data MSE and RMSE:
test_mse = mean_squared_error(preds, y_test)
print('MSE = ', test_mse)
print('RMSE = ', np.sqrt(test_mse))
# Out:
# MSE =  0.20408501723728467
# RMSE =  0.45175769748537176

# %%
# Calculate and display training data MSE and RMSE:
train_preds = model.predict(X_train_sc)
train_mse = mean_squared_error(train_preds, y_train)
print('MSE = ', train_mse)
print('RMSE = ', np.sqrt(train_mse))
# Out:
# MSE =  0.025312326386069717
# RMSE =  0.15909848015009356
