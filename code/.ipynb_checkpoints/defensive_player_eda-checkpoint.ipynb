# %%
import pandas as pd
import numpy as np
import props as p

# %matplotlib inline

# %%
# Top NFL defensive players 2010 - 2018.

# Passing:
top_d_18 = pd.read_csv('../data/top_nfl_players/defense/top_performance/d_perform_18.csv')
top_d_17 = pd.read_csv('../data/top_nfl_players/defense/top_performance/d_perform_17.csv')
top_d_16 = pd.read_csv('../data/top_nfl_players/defense/top_performance/d_perform_16.csv')
top_d_15 = pd.read_csv('../data/top_nfl_players/defense/top_performance/d_perform_15.csv')

# %%
# Add a new column to represent the year associated with best defensive player's performance.

top_d_18['Year'] = 2018
top_d_17['Year'] = 2017
top_d_16['Year'] = 2016
top_d_15['Year'] = 2015

# %%
# Assignment of names to all top defensive player dataframes.

top_d_18.name = 'Top NFL Defensive Players of 2018'
top_d_17.name = 'Top NFL Defensive Players of 2017'
top_d_16.name = 'Top NFL Defensive Players of 2016'
top_d_15.name = 'Top NFL Defensive Players of 2015'

# %%
# Add all dataframes to a list to enable usage of print_props funtion.
top_d_dfs = [top_d_18, top_d_17, top_d_16, top_d_15]

# %%
# Preview first 5 rows of top defensive player dataframes:
p.print_props(top_d_dfs, '.head()')
# Out:
# 	First 5 rows of DataFrame: Top NFL Defensive Players of 2018
# ----------------------------------------
#    Rank            Name Team Position  Played  SoloTackles  AssistedTackles  \
# 0     1  Darius Leonard  IND      OLB      15          111               52
# 1     2    Aaron Donald  LAR       DT      16           41               18
# 2     3         JJ Watt  HOU       DE      16           47               14
# 3     4    Luke Kuechly  CAR      ILB      16           93               37
# 4     5  Cory Littleton  LAR      ILB      16           90               35
#
#    TacklesForLoss  Sacks  SackYards  QuarterbackHits  PassesDefended  \
# 0            16.5    7.0       48.0                8               8
# 1            30.0   20.5      183.5               41               1
# 2            24.0   16.0      126.0               29               4
# 3            24.5    2.0        8.0                5               6
# ...

# %%
# Preview data types of top defensive player dataframes:
p.print_props(top_d_dfs, '.dtypes')
# Out:
# 	Data Types of DataFrame: Top NFL Defensive Players of 2018
# ----------------------------------------
# Rank                      int64
# Name                     object
# Team                     object
# Position                 object
# Played                    int64
# SoloTackles               int64
# AssistedTackles           int64
# TacklesForLoss          float64
# Sacks                   float64
# SackYards               float64
# QuarterbackHits           int64
# PassesDefended            int64
# Interceptions             int64
# FumblesForced             int64
# FumblesRecovered          int64
# DefensiveTouchdowns       int64
# FantasyPointsPerGame    float64
# FantasyPoints           float64
# Year                      int64
# dtype: object
#
# 	Data Types of DataFrame: Top NFL Defensive Players of 2017
# ----------------------------------------
# Rank                      int64
# Name                     object
# Team                     object
# ...

# %%
# Preview column features of top defensive player dataframes:
p.print_props(top_d_dfs, '.columns')
# Out:
# 	Column Features of DataFrame: Top NFL Defensive Players of 2018
# ----------------------------------------
# Index(['Rank', 'Name', 'Team', 'Position', 'Played', 'SoloTackles',
#        'AssistedTackles', 'TacklesForLoss', 'Sacks', 'SackYards',
#        'QuarterbackHits', 'PassesDefended', 'Interceptions', 'FumblesForced',
#        'FumblesRecovered', 'DefensiveTouchdowns', 'FantasyPointsPerGame',
#        'FantasyPoints', 'Year'],
#       dtype='object')
#
# 	Column Features of DataFrame: Top NFL Defensive Players of 2017
# ----------------------------------------
# Index(['Rank', 'Name', 'Team', 'Position', 'Played', 'SoloTackles',
#        'AssistedTackles', 'TacklesForLoss', 'Sacks', 'SackYards',
#        'QuarterbackHits', 'PassesDefended', 'Interceptions', 'FumblesForced',
#        'FumblesRecovered', 'DefensiveTouchdowns', 'FantasyPointsPerGame',
#        'FantasyPoints', 'Year'],
#       dtype='object')
#
# 	Column Features of DataFrame: Top NFL Defensive Players of 2016
# ...

# %%
# Preview shape of top defensive player dataframes:
p.print_props(top_d_dfs, '.shape')
# Out:
# 	Shape of DataFrame: Top NFL Defensive Players of 2018
# ----------------------------------------
# (300, 19)
#
# 	Shape of DataFrame: Top NFL Defensive Players of 2017
# ----------------------------------------
# (300, 19)
#
# 	Shape of DataFrame: Top NFL Defensive Players of 2016
# ----------------------------------------
# (300, 19)
#
# 	Shape of DataFrame: Top NFL Defensive Players of 2015
# ----------------------------------------
# (300, 19)

# %%
# Preview columns with null values of top defensive player dataframes:
p.print_props(top_d_dfs, '.isnull().sum()')
# Out:
# 	Null Values in DataFrame: Top NFL Defensive Players of 2018
# ----------------------------------------
# Rank                    0
# Name                    0
# Team                    0
# Position                0
# Played                  0
# SoloTackles             0
# AssistedTackles         0
# TacklesForLoss          0
# Sacks                   0
# SackYards               0
# QuarterbackHits         0
# PassesDefended          0
# Interceptions           0
# FumblesForced           0
# FumblesRecovered        0
# DefensiveTouchdowns     0
# FantasyPointsPerGame    0
# FantasyPoints           0
# Year                    0
# dtype: int64
#
# 	Null Values in DataFrame: Top NFL Defensive Players of 2017
# ----------------------------------------
# Rank                    0
# Name                    0
# Team                    0
# Position                0
# Played                  0
# SoloTackles             0
# AssistedTackles         0
# TacklesForLoss          0
# ...
