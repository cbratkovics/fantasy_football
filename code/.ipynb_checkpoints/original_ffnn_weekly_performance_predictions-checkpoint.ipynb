# %%
# DataFrame manipulation libraries:
import pandas as pd
import numpy as np
import props as p

# Visualization libraries:
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Evaluation and processing libraries:
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Keras libraries:
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, Dropout, GRU
from keras.optimizers import Adam
from keras.preprocessing.sequence import TimeseriesGenerator
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv('../clean_data/weekly_player_data_2015_to_2018_more_columns.csv')
df.head()
# Out:
#          Date  Rank            Name Team Position  Week Opponent  \
# 0  2015-09-13     1     Carlos Hyde   SF       RB     1      MIN
# 1  2015-09-13     2       Tom Brady   NE       QB     1      PIT
# 2  2015-09-13     3  Rob Gronkowski   NE       TE     1      PIT
# 3  2015-09-13     4     Julio Jones  ATL       WR     1      PHI
# 4  2015-09-13     5   Carson Palmer  ARI       QB     1       NO
#
#    PassingYards  PassingTouchdowns  PassingInterceptions  RushingYards  \
# 0             0                  0                     0           168
# 1           288                  4                     0             1
# 2             0                  0                     0             0
# 3             0                  0                     0             0
# 4           307                  3                     0            14
#
#    RushingTouchdowns  Receptions  ReceivingYards  ReceivingTouchdowns  \
# 0                  2           2              14                    0
# 1                  0           0               0                    0
# 2                  0           5              94                    3
# 3                  0           9             141                    2
# 4                  0           0               0                    0
#
#    FumblesLost  FantasyPoints
# 0            0          30.20
# 1            0          27.62
# 2            0          27.40
# 3            0          26.10
# 4            0          25.68

# %%
df['Date'] = pd.to_datetime(df['Date'], format = '%Y-%m-%d')
df.dtypes
# Out:
# Date                    datetime64[ns]
# Rank                             int64
# Name                            object
# Team                            object
# Position                        object
# Week                             int64
# Opponent                        object
# PassingYards                     int64
# PassingTouchdowns                int64
# PassingInterceptions             int64
# RushingYards                     int64
# RushingTouchdowns                int64
# Receptions                       int64
# ReceivingYards                   int64
# ReceivingTouchdowns              int64
# FumblesLost                      int64
# FantasyPoints                  float64
# dtype: object

# %%
df.set_index('Date', inplace=True)
df.sort_index(inplace=True)
df.head()
# Out:
#             Rank            Name Team Position  Week Opponent  PassingYards  \
# Date
# 2015-09-13     1     Carlos Hyde   SF       RB     1      MIN             0
# 2015-09-13     2       Tom Brady   NE       QB     1      PIT           288
# 2015-09-13     3  Rob Gronkowski   NE       TE     1      PIT             0
# 2015-09-13     4     Julio Jones  ATL       WR     1      PHI             0
# 2015-09-13     5   Carson Palmer  ARI       QB     1       NO           307
#
#             PassingTouchdowns  PassingInterceptions  RushingYards  \
# Date
# 2015-09-13                  0                     0           168
# 2015-09-13                  4                     0             1
# 2015-09-13                  0                     0             0
# 2015-09-13                  0                     0             0
# 2015-09-13                  3                     0            14
#
#             RushingTouchdowns  Receptions  ReceivingYards  \
# Date
# 2015-09-13                  2           2              14
# 2015-09-13                  0           0               0
# 2015-09-13                  0           5              94
# 2015-09-13                  0           9             141
# 2015-09-13                  0           0               0
#
#             ReceivingTouchdowns  FumblesLost  FantasyPoints
# Date
# 2015-09-13                    0            0          30.20
# 2015-09-13                    0            0          27.62
# 2015-09-13                    3            0          27.40
# 2015-09-13                    2            0          26.10
# 2015-09-13                    0            0          25.68

# %%
features = [col for col in df.columns if col not in ['Name', 'Team', 'Position', 'Opponent', 'FantasyPoints']]
df[features] = df[features].astype(float)
X = df[[col for col in df.columns if col != 'FantasyPoints']]
y = df['FantasyPoints']

# %%
X.dtypes
# Out:
# Rank                    float64
# Name                     object
# Team                     object
# Position                 object
# Week                    float64
# Opponent                 object
# PassingYards            float64
# PassingTouchdowns       float64
# PassingInterceptions    float64
# RushingYards            float64
# RushingTouchdowns       float64
# Receptions              float64
# ReceivingYards          float64
# ReceivingTouchdowns     float64
# FumblesLost             float64
# dtype: object

# %%
y.head()
# Out:
# Date
# 2015-09-13    30.20
# 2015-09-13    27.62
# 2015-09-13    27.40
# 2015-09-13    26.10
# 2015-09-13    25.68
# Name: FantasyPoints, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
ss = StandardScaler()
X_train_sc = ss.fit_transform(X_train.drop(columns = ['Name', 'Team', 'Position', 'Opponent']))
X_test_sc = ss.transform(X_test.drop(columns = ['Name', 'Team', 'Position', 'Opponent']))

# %%
X_test_sc[0:5]
# Out:
# array([[ 0.40830156,  0.61767345, -0.32569876, -0.26948036, -0.21607813,
#          0.32653258, -0.25192244, -0.51896593, -0.4531034 , -0.38336799,
#         -0.20342918],
#        [-0.70924942,  1.23005031, -0.32569876, -0.26948036, -0.21607813,
#          2.73555666, -0.25192244, -0.09110847, -0.3581574 , -0.38336799,
#         -0.20342918],
#        [-0.9255496 ,  1.23005031, -0.32569876, -0.26948036, -0.21607813,
#         -0.44925484, -0.25192244,  1.19246392,  0.90778923,  2.06060297,
#         -0.20342918],
#        [-1.33411663,  1.63830154, -0.32569876, -0.26948036, -0.21607813,
#         -0.44925484, -0.25192244,  1.62032138,  2.17373587,  2.06060297,
#         -0.20342918],
#        [ 0.50443497,  0.61767345, -0.32569876, -0.26948036, -0.21607813,
#         -0.04094567, -0.25192244, -0.51896593, -0.42145473, -0.38336799,
#         -0.20342918]])

# %%
model = Sequential()
model.add(Dense(121, activation='relu', input_shape=(11,)))
model.add(Dense(99, activation='relu'))
model.add(Dense(66, activation='relu'))
model.add(Dense(33, activation='relu'))
model.add(Dense(22, activation='relu'))
model.add(Dense(11, activation='relu'))
# model.add(Dense(2, activation='relu'))
model.add(Dense(1))
# Out:
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.compile(loss='mse', optimizer='adam', metrics=['mae'])

# %%
history = model.fit(X_train_sc, y_train, validation_data=(X_test_sc, y_test), epochs=120, batch_size=256)
# Out:
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 15300 samples, validate on 5100 samples
# Epoch 1/120
# 15300/15300 [==============================] - 1s 43us/step - loss: 28.1260 - mean_absolute_error: 3.0108 - val_loss: 1.1671 - val_mean_absolute_error: 0.7968
# Epoch 2/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.7424 - mean_absolute_error: 0.6300 - val_loss: 0.5158 - val_mean_absolute_error: 0.4986
# Epoch 3/120
# 15300/15300 [==============================] - 0s 15us/step - loss: 0.3625 - mean_absolute_error: 0.4213 - val_loss: 0.3266 - val_mean_absolute_error: 0.3879
# Epoch 4/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.2399 - mean_absolute_error: 0.3387 - val_loss: 0.2419 - val_mean_absolute_error: 0.3239
# Epoch 5/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.1912 - mean_absolute_error: 0.2991 - val_loss: 0.1973 - val_mean_absolute_error: 0.2856
# Epoch 6/120
# 15300/15300 [==============================] - 0s 16us/step - loss: 0.1621 - mean_absolute_error: 0.2667 - val_loss: 0.1726 - val_mean_absolute_error: 0.2547
# Epoch 7/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.1381 - mean_absolute_error: 0.2387 - val_loss: 0.1541 - val_mean_absolute_error: 0.2373
# Epoch 8/120
# 15300/15300 [==============================] - 0s 15us/step - loss: 0.1234 - mean_absolute_error: 0.2167 - val_loss: 0.1420 - val_mean_absolute_error: 0.2152
# Epoch 9/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.1128 - mean_absolute_error: 0.2014 - val_loss: 0.1300 - val_mean_absolute_error: 0.1990
# Epoch 10/120
# 15300/15300 [==============================] - 0s 16us/step - loss: 0.1066 - mean_absolute_error: 0.1915 - val_loss: 0.1263 - val_mean_absolute_error: 0.1912
# Epoch 11/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.1010 - mean_absolute_error: 0.1827 - val_loss: 0.1276 - val_mean_absolute_error: 0.1914
# Epoch 12/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.0955 - mean_absolute_error: 0.1745 - val_loss: 0.1173 - val_mean_absolute_error: 0.1708
# Epoch 13/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.0912 - mean_absolute_error: 0.1669 - val_loss: 0.1122 - val_mean_absolute_error: 0.1614
# Epoch 14/120
# 15300/15300 [==============================] - 0s 16us/step - loss: 0.0871 - mean_absolute_error: 0.1589 - val_loss: 0.1135 - val_mean_absolute_error: 0.1800
# Epoch 15/120
# 15300/15300 [==============================] - 0s 18us/step - loss: 0.0875 - mean_absolute_error: 0.1605 - val_loss: 0.1397 - val_mean_absolute_error: 0.2247
# Epoch 16/120
# 15300/15300 [==============================] - 0s 16us/step - loss: 0.0845 - mean_absolute_error: 0.1554 - val_loss: 0.1034 - val_mean_absolute_error: 0.1534
# Epoch 17/120
# 15300/15300 [==============================] - 0s 18us/step - loss: 0.0803 - mean_absolute_error: 0.1494 - val_loss: 0.0966 - val_mean_absolute_error: 0.1429
# Epoch 18/120
# 15300/15300 [==============================] - 0s 18us/step - loss: 0.0768 - mean_absolute_error: 0.1418 - val_loss: 0.1260 - val_mean_absolute_error: 0.1784
# Epoch 19/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.0842 - mean_absolute_error: 0.1534 - val_loss: 0.0960 - val_mean_absolute_error: 0.1532
# Epoch 20/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.0758 - mean_absolute_error: 0.1420 - val_loss: 0.0960 - val_mean_absolute_error: 0.1399
# Epoch 21/120
# 15300/15300 [==============================] - 0s 18us/step - loss: 0.0757 - mean_absolute_error: 0.1386 - val_loss: 0.0928 - val_mean_absolute_error: 0.1528
# Epoch 22/120
# 15300/15300 [==============================] - 0s 18us/step - loss: 0.0728 - mean_absolute_error: 0.1351 - val_loss: 0.0905 - val_mean_absolute_error: 0.1459
# Epoch 23/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.0701 - mean_absolute_error: 0.1304 - val_loss: 0.0856 - val_mean_absolute_error: 0.1455
# Epoch 24/120
# 15300/15300 [==============================] - 0s 16us/step - loss: 0.0703 - mean_absolute_error: 0.1294 - val_loss: 0.0908 - val_mean_absolute_error: 0.1512
# Epoch 25/120
# 15300/15300 [==============================] - 0s 16us/step - loss: 0.0719 - mean_absolute_error: 0.1327 - val_loss: 0.1083 - val_mean_absolute_error: 0.1828
# Epoch 26/120
# 15300/15300 [==============================] - 0s 18us/step - loss: 0.0690 - mean_absolute_error: 0.1328 - val_loss: 0.0803 - val_mean_absolute_error: 0.1225
# Epoch 27/120
# 15300/15300 [==============================] - 0s 16us/step - loss: 0.0659 - mean_absolute_error: 0.1218 - val_loss: 0.0771 - val_mean_absolute_error: 0.1281
# Epoch 28/120
# 15300/15300 [==============================] - 0s 18us/step - loss: 0.0672 - mean_absolute_error: 0.1272 - val_loss: 0.0795 - val_mean_absolute_error: 0.1162
# Epoch 29/120
# 15300/15300 [==============================] - 0s 18us/step - loss: 0.0676 - mean_absolute_error: 0.1259 - val_loss: 0.0776 - val_mean_absolute_error: 0.1299
# Epoch 30/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.0668 - mean_absolute_error: 0.1254 - val_loss: 0.0764 - val_mean_absolute_error: 0.1210
# Epoch 31/120
# 15300/15300 [==============================] - 0s 18us/step - loss: 0.0673 - mean_absolute_error: 0.1262 - val_loss: 0.0814 - val_mean_absolute_error: 0.1397
# Epoch 32/120
# 15300/15300 [==============================] - 0s 18us/step - loss: 0.0661 - mean_absolute_error: 0.1258 - val_loss: 0.0853 - val_mean_absolute_error: 0.1574
# Epoch 33/120
# 15300/15300 [==============================] - 0s 19us/step - loss: 0.0655 - mean_absolute_error: 0.1232 - val_loss: 0.0938 - val_mean_absolute_error: 0.1492
# Epoch 34/120
# 15300/15300 [==============================] - 0s 19us/step - loss: 0.0635 - mean_absolute_error: 0.1190 - val_loss: 0.0770 - val_mean_absolute_error: 0.1247
# Epoch 35/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.0638 - mean_absolute_error: 0.1183 - val_loss: 0.0724 - val_mean_absolute_error: 0.1156
# Epoch 36/120
# 15300/15300 [==============================] - 0s 19us/step - loss: 0.0630 - mean_absolute_error: 0.1167 - val_loss: 0.0728 - val_mean_absolute_error: 0.1051
# Epoch 37/120
# 15300/15300 [==============================] - 0s 18us/step - loss: 0.0598 - mean_absolute_error: 0.1098 - val_loss: 0.0727 - val_mean_absolute_error: 0.1138
# Epoch 38/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.0731 - mean_absolute_error: 0.1335 - val_loss: 0.1141 - val_mean_absolute_error: 0.1609
# Epoch 39/120
# 15300/15300 [==============================] - 0s 16us/step - loss: 0.0742 - mean_absolute_error: 0.1363 - val_loss: 0.0867 - val_mean_absolute_error: 0.1287
# Epoch 40/120
# 15300/15300 [==============================] - 0s 18us/step - loss: 0.0645 - mean_absolute_error: 0.1181 - val_loss: 0.0718 - val_mean_absolute_error: 0.1081
# Epoch 41/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.0677 - mean_absolute_error: 0.1231 - val_loss: 0.0740 - val_mean_absolute_error: 0.1132
# Epoch 42/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.0620 - mean_absolute_error: 0.1147 - val_loss: 0.0701 - val_mean_absolute_error: 0.1099
# Epoch 43/120
# 15300/15300 [==============================] - 0s 18us/step - loss: 0.0590 - mean_absolute_error: 0.1081 - val_loss: 0.0781 - val_mean_absolute_error: 0.1088
# Epoch 44/120
# 15300/15300 [==============================] - 0s 18us/step - loss: 0.0594 - mean_absolute_error: 0.1094 - val_loss: 0.0719 - val_mean_absolute_error: 0.1038
# Epoch 45/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.0587 - mean_absolute_error: 0.1070 - val_loss: 0.0695 - val_mean_absolute_error: 0.1042
# Epoch 46/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.0594 - mean_absolute_error: 0.1108 - val_loss: 0.0838 - val_mean_absolute_error: 0.1407
# Epoch 47/120
# 15300/15300 [==============================] - 0s 16us/step - loss: 0.0599 - mean_absolute_error: 0.1099 - val_loss: 0.0679 - val_mean_absolute_error: 0.1043
# Epoch 48/120
# 15300/15300 [==============================] - 0s 14us/step - loss: 0.0578 - mean_absolute_error: 0.1063 - val_loss: 0.0797 - val_mean_absolute_error: 0.1435
# Epoch 49/120
# 15300/15300 [==============================] - 0s 14us/step - loss: 0.0592 - mean_absolute_error: 0.1100 - val_loss: 0.0725 - val_mean_absolute_error: 0.1145
# Epoch 50/120
# 15300/15300 [==============================] - 0s 14us/step - loss: 0.0569 - mean_absolute_error: 0.1070 - val_loss: 0.0706 - val_mean_absolute_error: 0.1145
# Epoch 51/120
# 15300/15300 [==============================] - 0s 14us/step - loss: 0.0567 - mean_absolute_error: 0.1058 - val_loss: 0.0811 - val_mean_absolute_error: 0.1261
# Epoch 52/120
# 15300/15300 [==============================] - 0s 14us/step - loss: 0.0585 - mean_absolute_error: 0.1098 - val_loss: 0.0687 - val_mean_absolute_error: 0.1090
# Epoch 53/120
# 15300/15300 [==============================] - 0s 15us/step - loss: 0.0614 - mean_absolute_error: 0.1140 - val_loss: 0.0763 - val_mean_absolute_error: 0.1308
# Epoch 54/120
# 15300/15300 [==============================] - 0s 15us/step - loss: 0.0583 - mean_absolute_error: 0.1085 - val_loss: 0.0683 - val_mean_absolute_error: 0.1101
# Epoch 55/120
# 15300/15300 [==============================] - 0s 14us/step - loss: 0.0573 - mean_absolute_error: 0.1075 - val_loss: 0.0715 - val_mean_absolute_error: 0.1041
# Epoch 56/120
# 15300/15300 [==============================] - 0s 15us/step - loss: 0.0564 - mean_absolute_error: 0.1044 - val_loss: 0.0843 - val_mean_absolute_error: 0.1610
# Epoch 57/120
# 15300/15300 [==============================] - 0s 15us/step - loss: 0.0615 - mean_absolute_error: 0.1146 - val_loss: 0.0799 - val_mean_absolute_error: 0.1332
# Epoch 58/120
# 15300/15300 [==============================] - 0s 15us/step - loss: 0.0637 - mean_absolute_error: 0.1198 - val_loss: 0.0819 - val_mean_absolute_error: 0.1303
# Epoch 59/120
# 15300/15300 [==============================] - 0s 16us/step - loss: 0.0584 - mean_absolute_error: 0.1066 - val_loss: 0.0760 - val_mean_absolute_error: 0.1364
# Epoch 60/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.0617 - mean_absolute_error: 0.1124 - val_loss: 0.0687 - val_mean_absolute_error: 0.1139
# Epoch 61/120
# 15300/15300 [==============================] - 0s 15us/step - loss: 0.0570 - mean_absolute_error: 0.1049 - val_loss: 0.0695 - val_mean_absolute_error: 0.1107
# Epoch 62/120
# 15300/15300 [==============================] - 0s 15us/step - loss: 0.0550 - mean_absolute_error: 0.0994 - val_loss: 0.0708 - val_mean_absolute_error: 0.1073
# Epoch 63/120
# 15300/15300 [==============================] - 0s 15us/step - loss: 0.0554 - mean_absolute_error: 0.1055 - val_loss: 0.0695 - val_mean_absolute_error: 0.1055
# Epoch 64/120
# 15300/15300 [==============================] - 0s 16us/step - loss: 0.0606 - mean_absolute_error: 0.1121 - val_loss: 0.0654 - val_mean_absolute_error: 0.0915
# Epoch 65/120
# 15300/15300 [==============================] - 0s 15us/step - loss: 0.0573 - mean_absolute_error: 0.1047 - val_loss: 0.0694 - val_mean_absolute_error: 0.1071
# Epoch 66/120
# 15300/15300 [==============================] - 0s 16us/step - loss: 0.0590 - mean_absolute_error: 0.1102 - val_loss: 0.0752 - val_mean_absolute_error: 0.1208
# Epoch 67/120
# 15300/15300 [==============================] - 0s 15us/step - loss: 0.0543 - mean_absolute_error: 0.1020 - val_loss: 0.0709 - val_mean_absolute_error: 0.1188
# Epoch 68/120
# 15300/15300 [==============================] - 0s 18us/step - loss: 0.0570 - mean_absolute_error: 0.1054 - val_loss: 0.0735 - val_mean_absolute_error: 0.1062
# Epoch 69/120
# 15300/15300 [==============================] - 0s 15us/step - loss: 0.0582 - mean_absolute_error: 0.1103 - val_loss: 0.0792 - val_mean_absolute_error: 0.1111
# Epoch 70/120
# 15300/15300 [==============================] - 0s 16us/step - loss: 0.0593 - mean_absolute_error: 0.1101 - val_loss: 0.0714 - val_mean_absolute_error: 0.1167
# Epoch 71/120
# 15300/15300 [==============================] - 0s 16us/step - loss: 0.0588 - mean_absolute_error: 0.1112 - val_loss: 0.0775 - val_mean_absolute_error: 0.1324
# Epoch 72/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.0615 - mean_absolute_error: 0.1168 - val_loss: 0.0784 - val_mean_absolute_error: 0.1068
# Epoch 73/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.0571 - mean_absolute_error: 0.1044 - val_loss: 0.0687 - val_mean_absolute_error: 0.1075
# Epoch 74/120
# 15300/15300 [==============================] - 0s 18us/step - loss: 0.0541 - mean_absolute_error: 0.0993 - val_loss: 0.0666 - val_mean_absolute_error: 0.1026
# Epoch 75/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.0535 - mean_absolute_error: 0.0991 - val_loss: 0.0662 - val_mean_absolute_error: 0.0977
# Epoch 76/120
# 15300/15300 [==============================] - 0s 19us/step - loss: 0.0558 - mean_absolute_error: 0.1046 - val_loss: 0.0797 - val_mean_absolute_error: 0.1432
# Epoch 77/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.0677 - mean_absolute_error: 0.1300 - val_loss: 0.0771 - val_mean_absolute_error: 0.1273
# Epoch 78/120
# 15300/15300 [==============================] - 0s 18us/step - loss: 0.0540 - mean_absolute_error: 0.0977 - val_loss: 0.0703 - val_mean_absolute_error: 0.1134
# Epoch 79/120
# 15300/15300 [==============================] - 0s 16us/step - loss: 0.0537 - mean_absolute_error: 0.0963 - val_loss: 0.0714 - val_mean_absolute_error: 0.1049
# Epoch 80/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.0539 - mean_absolute_error: 0.1026 - val_loss: 0.0868 - val_mean_absolute_error: 0.1394
# Epoch 81/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.0525 - mean_absolute_error: 0.0996 - val_loss: 0.0669 - val_mean_absolute_error: 0.0907
# Epoch 82/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.0541 - mean_absolute_error: 0.1018 - val_loss: 0.0645 - val_mean_absolute_error: 0.0980
# Epoch 83/120
# 15300/15300 [==============================] - 0s 15us/step - loss: 0.0560 - mean_absolute_error: 0.1075 - val_loss: 0.0711 - val_mean_absolute_error: 0.1222
# Epoch 84/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.0584 - mean_absolute_error: 0.1125 - val_loss: 0.0748 - val_mean_absolute_error: 0.1009
# Epoch 85/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.0552 - mean_absolute_error: 0.1045 - val_loss: 0.0740 - val_mean_absolute_error: 0.0955
# Epoch 86/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.0526 - mean_absolute_error: 0.0976 - val_loss: 0.0646 - val_mean_absolute_error: 0.0877
# Epoch 87/120
# 15300/15300 [==============================] - 0s 16us/step - loss: 0.0592 - mean_absolute_error: 0.1141 - val_loss: 0.0763 - val_mean_absolute_error: 0.1153
# Epoch 88/120
# 15300/15300 [==============================] - 0s 16us/step - loss: 0.0600 - mean_absolute_error: 0.1130 - val_loss: 0.0762 - val_mean_absolute_error: 0.1213
# Epoch 89/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.0578 - mean_absolute_error: 0.1168 - val_loss: 0.0689 - val_mean_absolute_error: 0.1071
# Epoch 90/120
# 15300/15300 [==============================] - 0s 15us/step - loss: 0.0545 - mean_absolute_error: 0.1018 - val_loss: 0.0743 - val_mean_absolute_error: 0.1254
# Epoch 91/120
# 15300/15300 [==============================] - 0s 16us/step - loss: 0.0514 - mean_absolute_error: 0.0940 - val_loss: 0.0654 - val_mean_absolute_error: 0.0936
# Epoch 92/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.0481 - mean_absolute_error: 0.0869 - val_loss: 0.0700 - val_mean_absolute_error: 0.1173
# Epoch 93/120
# 15300/15300 [==============================] - 0s 19us/step - loss: 0.0552 - mean_absolute_error: 0.1045 - val_loss: 0.0826 - val_mean_absolute_error: 0.1553
# Epoch 94/120
# 15300/15300 [==============================] - 0s 18us/step - loss: 0.0606 - mean_absolute_error: 0.1144 - val_loss: 0.0700 - val_mean_absolute_error: 0.0960
# Epoch 95/120
# 15300/15300 [==============================] - 0s 15us/step - loss: 0.0541 - mean_absolute_error: 0.1019 - val_loss: 0.0673 - val_mean_absolute_error: 0.0940
# Epoch 96/120
# 15300/15300 [==============================] - 0s 15us/step - loss: 0.0517 - mean_absolute_error: 0.0948 - val_loss: 0.0693 - val_mean_absolute_error: 0.1173
# Epoch 97/120
# 15300/15300 [==============================] - 0s 14us/step - loss: 0.0562 - mean_absolute_error: 0.1066 - val_loss: 0.0698 - val_mean_absolute_error: 0.1105
# Epoch 98/120
# 15300/15300 [==============================] - 0s 14us/step - loss: 0.0528 - mean_absolute_error: 0.0983 - val_loss: 0.0669 - val_mean_absolute_error: 0.0892
# Epoch 99/120
# 15300/15300 [==============================] - 0s 15us/step - loss: 0.0575 - mean_absolute_error: 0.1069 - val_loss: 0.1002 - val_mean_absolute_error: 0.1589
# Epoch 100/120
# 15300/15300 [==============================] - 0s 14us/step - loss: 0.0624 - mean_absolute_error: 0.1185 - val_loss: 0.0900 - val_mean_absolute_error: 0.1536
# Epoch 101/120
# 15300/15300 [==============================] - 0s 14us/step - loss: 0.0549 - mean_absolute_error: 0.1037 - val_loss: 0.0699 - val_mean_absolute_error: 0.0981
# Epoch 102/120
# 15300/15300 [==============================] - 0s 15us/step - loss: 0.0520 - mean_absolute_error: 0.0975 - val_loss: 0.0731 - val_mean_absolute_error: 0.1082
# Epoch 103/120
# 15300/15300 [==============================] - 0s 15us/step - loss: 0.0559 - mean_absolute_error: 0.1050 - val_loss: 0.0707 - val_mean_absolute_error: 0.1193
# Epoch 104/120
# 15300/15300 [==============================] - 0s 15us/step - loss: 0.0511 - mean_absolute_error: 0.0952 - val_loss: 0.0670 - val_mean_absolute_error: 0.0920
# Epoch 105/120
# 15300/15300 [==============================] - 0s 14us/step - loss: 0.0511 - mean_absolute_error: 0.0950 - val_loss: 0.0692 - val_mean_absolute_error: 0.1176
# Epoch 106/120
# 15300/15300 [==============================] - 0s 15us/step - loss: 0.0528 - mean_absolute_error: 0.0999 - val_loss: 0.0706 - val_mean_absolute_error: 0.1088
# Epoch 107/120
# 15300/15300 [==============================] - 0s 15us/step - loss: 0.0560 - mean_absolute_error: 0.1053 - val_loss: 0.0720 - val_mean_absolute_error: 0.1202
# Epoch 108/120
# 15300/15300 [==============================] - 0s 17us/step - loss: 0.0506 - mean_absolute_error: 0.0977 - val_loss: 0.0712 - val_mean_absolute_error: 0.1121
# Epoch 109/120
# 15300/15300 [==============================] - 0s 15us/step - loss: 0.0486 - mean_absolute_error: 0.0899 - val_loss: 0.0738 - val_mean_absolute_error: 0.1207
# Epoch 110/120
# 15300/15300 [==============================] - 0s 15us/step - loss: 0.0524 - mean_absolute_error: 0.0998 - val_loss: 0.0767 - val_mean_absolute_error: 0.1130
# Epoch 111/120
# 15300/15300 [==============================] - 0s 15us/step - loss: 0.0589 - mean_absolute_error: 0.1166 - val_loss: 0.0671 - val_mean_absolute_error: 0.1008
# Epoch 112/120
# 15300/15300 [==============================] - 0s 16us/step - loss: 0.0530 - mean_absolute_error: 0.0996 - val_loss: 0.0665 - val_mean_absolute_error: 0.1032
# Epoch 113/120
# 15300/15300 [==============================] - 0s 15us/step - loss: 0.0547 - mean_absolute_error: 0.1020 - val_loss: 0.0796 - val_mean_absolute_error: 0.1219
# Epoch 114/120
# 15300/15300 [==============================] - 0s 14us/step - loss: 0.0520 - mean_absolute_error: 0.1003 - val_loss: 0.0694 - val_mean_absolute_error: 0.1065
# Epoch 115/120
# 15300/15300 [==============================] - 0s 16us/step - loss: 0.0530 - mean_absolute_error: 0.1047 - val_loss: 0.0671 - val_mean_absolute_error: 0.1091
# Epoch 116/120
# 15300/15300 [==============================] - 0s 16us/step - loss: 0.0555 - mean_absolute_error: 0.1063 - val_loss: 0.0679 - val_mean_absolute_error: 0.0986
# Epoch 117/120
# 15300/15300 [==============================] - 0s 16us/step - loss: 0.0584 - mean_absolute_error: 0.1138 - val_loss: 0.0696 - val_mean_absolute_error: 0.1181
# Epoch 118/120
# 15300/15300 [==============================] - 0s 15us/step - loss: 0.0488 - mean_absolute_error: 0.0922 - val_loss: 0.0670 - val_mean_absolute_error: 0.0837
# Epoch 119/120
# 15300/15300 [==============================] - 0s 16us/step - loss: 0.0578 - mean_absolute_error: 0.1089 - val_loss: 0.0796 - val_mean_absolute_error: 0.1311
# Epoch 120/120
# 15300/15300 [==============================] - 0s 16us/step - loss: 0.0549 - mean_absolute_error: 0.1062 - val_loss: 0.0662 - val_mean_absolute_error: 0.1028

# %%
preds = model.predict(X_test_sc)
preds
# Out:
# array([[ 2.990648 ],
#        [ 9.1175165],
#        [11.3439045],
#        ...,
#        [ 0.4666868],
#        [ 4.5155544],
#        [ 0.717507 ]], dtype=float32)

# %%
y_test.head()
# Out:
# Date
# 2015-11-29     3.0
# 2016-12-18     9.2
# 2015-12-20    11.4
# 2018-12-30    15.4
# 2018-11-25     2.2
# Name: FantasyPoints, dtype: float64

# %%
train_loss = history.history['loss']
test_loss = history.history['val_loss']

plt.figure(figsize=(15, 10))

# Plot training and testing loss for the original model:
plt.plot(train_loss, label='Training loss', color='navy')
plt.plot(test_loss, label='Testing loss', color='skyblue')

plt.legend();

# plt.savefig('../images/FFNN_fantasy_predictions_loss_function_plot.png')

# %%
X_test.head()
# Out:
#              Rank             Name Team Position  Week Opponent  PassingYards  \
# Date
# 2015-11-29  181.0      Todd Gurley  LAR       RB  12.0      CIN           0.0
# 2016-12-18   88.0      Mark Ingram   NO       RB  15.0      ARI           0.0
# 2015-12-20   70.0   Rob Gronkowski   NE       TE  15.0      TEN           0.0
# 2018-12-30   36.0     Cole Beasley  DAL       WR  17.0      NYG           0.0
# 2018-11-25  189.0  Giovani Bernard  CIN       RB  12.0      CLE           0.0
#
#             PassingTouchdowns  PassingInterceptions  RushingYards  \
# Date
# 2015-11-29                0.0                   0.0          19.0
# 2016-12-18                0.0                   0.0          78.0
# 2015-12-20                0.0                   0.0           0.0
# 2018-12-30                0.0                   0.0           0.0
# 2018-11-25                0.0                   0.0          10.0
#
#             RushingTouchdowns  Receptions  ReceivingYards  \
# Date
# 2015-11-29                0.0         1.0            11.0
# 2016-12-18                0.0         2.0            14.0
# 2015-12-20                0.0         5.0            54.0
# 2018-12-30                0.0         6.0            94.0
# 2018-11-25                0.0         1.0            12.0
#
#             ReceivingTouchdowns  FumblesLost
# Date
# 2015-11-29                  0.0          0.0
# 2016-12-18                  0.0          0.0
# 2015-12-20                  1.0          0.0
# 2018-12-30                  1.0          0.0
# 2018-11-25                  0.0          0.0

# %%
len(preds)
# Out:
# 5100

# %%
X_test.shape
# Out:
# (5100, 15)

# %%
X_test['Predicted_FP'] = preds
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_test.head(10)
# Out:
#              Rank             Name Team Position  Week Opponent  PassingYards  \
# Date
# 2015-11-29  181.0      Todd Gurley  LAR       RB  12.0      CIN           0.0
# 2016-12-18   88.0      Mark Ingram   NO       RB  15.0      ARI           0.0
# 2015-12-20   70.0   Rob Gronkowski   NE       TE  15.0      TEN           0.0
# 2018-12-30   36.0     Cole Beasley  DAL       WR  17.0      NYG           0.0
# 2018-11-25  189.0  Giovani Bernard  CIN       RB  12.0      CLE           0.0
# 2016-12-25   59.0      Andy Dalton  CIN       QB  16.0      HOU         268.0
# 2018-10-21  217.0     Luke Willson  DET       TE   7.0      MIA           0.0
# 2017-10-15  250.0    Logan Paulsen   SF       TE   6.0      WAS           0.0
# 2017-12-17  247.0      James White   NE       RB  15.0      PIT           0.0
# 2015-11-29  174.0    Albert Wilson   KC       WR  12.0      BUF           0.0
#
#             PassingTouchdowns  PassingInterceptions  RushingYards  \
# Date
# 2015-11-29                0.0                   0.0          19.0
# 2016-12-18                0.0                   0.0          78.0
# 2015-12-20                0.0                   0.0           0.0
# 2018-12-30                0.0                   0.0           0.0
# 2018-11-25                0.0                   0.0          10.0
# 2016-12-25                1.0                   1.0           0.0
# 2018-10-21                0.0                   0.0           0.0
# 2017-10-15                0.0                   0.0           0.0
# 2017-12-17                0.0                   0.0           0.0
# 2015-11-29                0.0                   0.0           8.0
#
#             RushingTouchdowns  Receptions  ReceivingYards  \
# Date
# 2015-11-29                0.0         1.0            11.0
# 2016-12-18                0.0         2.0            14.0
# 2015-12-20                0.0         5.0            54.0
# 2018-12-30                0.0         6.0            94.0
# 2018-11-25                0.0         1.0            12.0
# 2016-12-25                0.0         0.0             0.0
# 2018-10-21                0.0         2.0             8.0
# 2017-10-15                0.0         0.0             0.0
# 2017-12-17                0.0         2.0             8.0
# 2015-11-29                0.0         3.0            25.0
#
#             ReceivingTouchdowns  FumblesLost  Predicted_FP
# Date
# 2015-11-29                  0.0          0.0      2.990648
# 2016-12-18                  0.0          0.0      9.117517
# 2015-12-20                  1.0          0.0     11.343904
# 2018-12-30                  1.0          0.0     15.448689
# 2018-11-25                  0.0          0.0      2.128088
# 2016-12-25                  0.0          0.0     12.804083
# 2018-10-21                  0.0          0.0      0.755603
# 2017-10-15                  0.0          0.0      0.000111
# 2017-12-17                  0.0          0.0      0.744247
# 2015-11-29                  0.0          0.0      3.308360

# %%
y_test.head()
# Out:
# Date
# 2015-11-29     3.0
# 2016-12-18     9.2
# 2015-12-20    11.4
# 2018-12-30    15.4
# 2018-11-25     2.2
# Name: FantasyPoints, dtype: float64

# %%
y_test.shape
# Out:
# (5100,)

# %%
X_test['FantasyPoints'] = y_test
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_test.head(10)
# Out:
#              Rank             Name Team Position  Week Opponent  PassingYards  \
# Date
# 2015-11-29  181.0      Todd Gurley  LAR       RB  12.0      CIN           0.0
# 2016-12-18   88.0      Mark Ingram   NO       RB  15.0      ARI           0.0
# 2015-12-20   70.0   Rob Gronkowski   NE       TE  15.0      TEN           0.0
# 2018-12-30   36.0     Cole Beasley  DAL       WR  17.0      NYG           0.0
# 2018-11-25  189.0  Giovani Bernard  CIN       RB  12.0      CLE           0.0
# 2016-12-25   59.0      Andy Dalton  CIN       QB  16.0      HOU         268.0
# 2018-10-21  217.0     Luke Willson  DET       TE   7.0      MIA           0.0
# 2017-10-15  250.0    Logan Paulsen   SF       TE   6.0      WAS           0.0
# 2017-12-17  247.0      James White   NE       RB  15.0      PIT           0.0
# 2015-11-29  174.0    Albert Wilson   KC       WR  12.0      BUF           0.0
#
#             PassingTouchdowns  PassingInterceptions  RushingYards  \
# Date
# 2015-11-29                0.0                   0.0          19.0
# 2016-12-18                0.0                   0.0          78.0
# 2015-12-20                0.0                   0.0           0.0
# 2018-12-30                0.0                   0.0           0.0
# 2018-11-25                0.0                   0.0          10.0
# 2016-12-25                1.0                   1.0           0.0
# 2018-10-21                0.0                   0.0           0.0
# 2017-10-15                0.0                   0.0           0.0
# 2017-12-17                0.0                   0.0           0.0
# 2015-11-29                0.0                   0.0           8.0
#
#             RushingTouchdowns  Receptions  ReceivingYards  \
# Date
# 2015-11-29                0.0         1.0            11.0
# 2016-12-18                0.0         2.0            14.0
# 2015-12-20                0.0         5.0            54.0
# 2018-12-30                0.0         6.0            94.0
# 2018-11-25                0.0         1.0            12.0
# 2016-12-25                0.0         0.0             0.0
# 2018-10-21                0.0         2.0             8.0
# 2017-10-15                0.0         0.0             0.0
# 2017-12-17                0.0         2.0             8.0
# 2015-11-29                0.0         3.0            25.0
#
#             ReceivingTouchdowns  FumblesLost  Predicted_FP  FantasyPoints
# Date
# 2015-11-29                  0.0          0.0      2.990648           3.00
# 2016-12-18                  0.0          0.0      9.117517           9.20
# 2015-12-20                  1.0          0.0     11.343904          11.40
# 2018-12-30                  1.0          0.0     15.448689          15.40
# 2018-11-25                  0.0          0.0      2.128088           2.20
# 2016-12-25                  0.0          0.0     12.804083          12.72
# 2018-10-21                  0.0          0.0      0.755603           0.80
# 2017-10-15                  0.0          0.0      0.000111           0.00
# 2017-12-17                  0.0          0.0      0.744247           0.80
# 2015-11-29                  0.0          0.0      3.308360           3.30

# %%
# Testing data MSE and RMSE:
y_hat = X_test['Predicted_FP']
y_true = X_test['FantasyPoints']
test_mse = mean_squared_error(y_hat, y_true)
print('MSE = ', test_mse)
print('RMSE = ', np.sqrt(test_mse))
# Out:
# MSE =  0.06617813177529443
# RMSE =  0.2572511064607778

# %%
X_train.head()
# Out:
#              Rank               Name Team Position  Week Opponent  \
# Date
# 2015-09-13  177.0    Marques Colston   NO       WR   1.0      ARI
# 2018-11-04  228.0        AJ McCarron  OAK       QB   9.0       SF
# 2018-09-23  213.0       Torrey Smith  CAR       WR   3.0      CIN
# 2018-09-16  283.0    Damien Williams   KC       RB   2.0      PIT
# 2017-11-05  233.0  Dwayne Washington  DET       RB   9.0       GB
#
#             PassingYards  PassingTouchdowns  PassingInterceptions  \
# Date
# 2015-09-13           0.0                0.0                   0.0
# 2018-11-04           8.0                0.0                   0.0
# 2018-09-23           0.0                0.0                   0.0
# 2018-09-16           0.0                0.0                   0.0
# 2017-11-05           0.0                0.0                   0.0
#
#             RushingYards  RushingTouchdowns  Receptions  ReceivingYards  \
# Date
# 2015-09-13           0.0                0.0         3.0            29.0
# 2018-11-04           0.0                0.0         0.0             0.0
# 2018-09-23           0.0                0.0         3.0            19.0
# 2018-09-16           0.0                0.0         1.0             2.0
# 2017-11-05           1.0                0.0         0.0             0.0
#
#             ReceivingTouchdowns  FumblesLost
# Date
# 2015-09-13                  0.0          0.0
# 2018-11-04                  0.0          0.0
# 2018-09-23                  0.0          0.0
# 2018-09-16                  0.0          0.0
# 2017-11-05                  0.0          0.0

# %%
X_train['FantasyPoints'] = y_train
X_train['Predicted_FP'] = model.predict(X_train_sc)

# Training data MSE and RMSE:
train_y_preds = X_train['Predicted_FP']
train_y = X_train['FantasyPoints']
train_mse = mean_squared_error(train_y_preds, train_y)
print('MSE = ', train_mse)
print('RMSE = ', np.sqrt(train_mse))
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# MSE =  0.046749314780422345
# RMSE =  0.2162158985376014
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
